# %% [markdown]
# <a href="https://colab.research.google.com/github/alizahedzadeh/self-explaination-thesis/blob/main/LLama3_1_70b_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Groq api
#
# In this notebook I used groq api for Inferece from `LLama-70B`

# %%
from google.colab import drive
drive.mount('/content/drive')
# !git clone https://alizahedzadeh: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>@github.com/alizahedzadeh/self-explaination-thesis.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /bin/bash: line 1: @github.com/alizahedzadeh/self-explaination-thesis.git: No such file or directory
