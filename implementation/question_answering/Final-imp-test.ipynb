# %%
from datasets import load_dataset
import pandas as pd
import logging
import time
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain_groq import ChatGroq
import os
from langchain_cohere import ChatCohere

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from IPython.display import display, HTML
import json

# %%
file_path = 'pes_arab_dataset.csv'  # Path for the CSV file
data = pd.read_csv(file_path)

# Sample 50 entries from the dataset
sampled_data = data.sample(n=5, random_state=42)

sampled_data
# Out:
#                                                   link  question_number  \
# 70   https://en.wikibooks.org/wiki/High_School_Eart...                1
# 827            https://en.wikivoyage.org/wiki/Paraguay                1
# 231  https://en.wikibooks.org/wiki/Wikijunior:Solar...                2
# 588  https://en.wikinews.org/wiki/Seven_killed_in_C...                2
# 39   https://en.wikibooks.org/wiki/Environmental_th...                1
#
#                                         flores_passage  \
# 70   بشر هزاران هزار سال از عدسی‌ها برای بزرگ‌نمایی...
# 827  گوارانی‌ها مهم‌ترین گروه بومی ساکن پاراگوئه شر...
# 231  خورشید پوسته‌ای شبیه کره زمین ندارد که بتوانید...
# 588  آن مرد ظاهراً یک خودروی سه‌چرخ مسلح به مواد من...
# 39   ما می توانیم زندگی دوستانه تری را با محیط زیست...
#
#                                               question  \
# 70   کدام یک از موارد زیر را انسان‌ها در قرن شانزده...
# 827  دوران استعمارگری که سه قرن طول کشید توسط کدام ...
# 231  با توجه به متن، کدام قسمت از خورشید از زمین قا...
# 588   مقامات چه اطلاعاتی درخصوص حمله تأیید کرده بودند؟
# 39   با توجه به متن، کدام مورد راه‌حلی قابل اجرا بر...
#
#                                   mc_answer1       mc_answer2  \
# 70                        استفاده از عدسی‌ها  بزرگنمایی اشیاء
# 827                                 پاراگوئه         Guaycurú
# 231                                    پوسته           پلاسما
# 588                           هویت هم‌دست‌ها      قومیت مظنون
# 39   تحریم انتخاب‌های سبک زندگی مصرف‌گرایانه           کنشگری
#
#            mc_answer3                        mc_answer4  correct_answer_num  \
# 70       ساخت عدسی‌ها                       ساخت تلسکوپ                   4
# 827        گورانی‌ها                   فاتحان اسپانیایی                   4
# 231           فوتوسفر                              مرکز                   3
# 588       انگیزه حمله          نام و نام خانوادگی مظنون                   2
# 39   یافتن ریشه مسئله  تبدیل شدن به متحد جنبش محیط زیست                   3
#
#       dialect          ds
# 70   pes_Arab  2023-06-07
# 827  pes_Arab  2023-06-07
# 231  pes_Arab  2023-06-07
# 588  pes_Arab  2023-06-07
# 39   pes_Arab  2023-06-07

# %%
os.environ['COHERE_API_KEY'] = 'SR3Jo6dFTyZHUdbKivgCKD54c7zxCj2fVREaKkbZ'

# %% [markdown]
# # Just predict

# %% [markdown]
# **Just predict answer function**

# %%
def just_predict(passage, question, options, llm):
    messages = [
        {
            "role": "system",
            "content": (
                "You will receive a `QUESTION` with multiple `ANSWER CHOICES` and a supporting `CONTEXT`. "
                "Your task is to determine the correct answer based on the information in the context.\n\n"
                "Select only one answer choice (1, 2, 3, or 4) based on your understanding of the context.\n"
                "   - Format: <answer>[Your CHOICE here]</answer>"
            )
        },
        {
            "role": "user",
            "content": (
                f"CONTEXT:\n{passage}\n\n"
                f"QUESTION:\n{question}\n\n"
                f"ANSWER CHOICES:\n1-{options[0]}\n2-{options[1]}\n3-{options[2]}\n4-{options[3]}"
            )
        }
    ]
    result = llm.invoke(messages)
    return result.content.strip()

# %% [markdown]
# **Predict then Explain**

# %%
def explain_then_predict():
    pass

# %% [markdown]
# **Explain then Predict**

# %%
def predict_then_explain():
    pass

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

# Function to check the API with custom parameters: model_name and temperature
def check_api_with_parameters(model_name, temperature):
    llm = ChatCohere(
        model=model_name,
        temperature=temperature,
        max_tokens=None,
        timeout=None,
        max_retries=2
    )
    return llm

# Function to predict the answer and save the full generation to a file
def predict_answer_and_save(passage, question, options, llm, generation_file):
    logging.info(f"Starting prediction for passage: {passage[:50]}... and question: {question}")
    try:
        # Define the messages based on the new prompt format
        messages = [
            {
                "role": "system",
                "content": (
                    "You will receive a `QUESTION` with multiple `ANSWER CHOICES` and a supporting `CONTEXT`. "
                    "Your task is to determine the correct answer based on the information in the context and to explain "
                    "your reasoning step-by-step, referencing key details from the context.\n\n"
                    "Follow these instructions for your response:\n\n"
                    "Select only one answer choice (1, 2, 3, or 4) based on your understanding of the context.\n"
                    "   - Format: <answer>[Your CHOICE here]</answer>\n\n"
                    "Provide a detailed, step-by-step explanation of how you arrived at the answer, focusing on the logical reasoning process. "
                    "Include references to relevant parts of the context to support each reasoning step. `The explanation must be in Persian.`\n"
                    "   - Format: <explanation>[Step-by-step reasoning and references to context here]</explanation>\n\n"
                    "Identify and quote the most relevant parts of the context that were essential in answering the question. "
                    "Only include the specific information that directly supports your chosen answer. `Ensure this is in Persian.`\n"
                    "   - Format: <highlight>[Key supporting context here]</highlight>\n\n"
                    "List the most important keywords from the context that are essential for understanding and answering the question. "
                    "`Provide keywords as a Python list, in Persian.`\n"
                    "   - Format: <keywords>[Relevant KEYWORDS here]</keywords>\n\n"
                    "---\n\n"
                    "`Guidelines for Self-Explanation`:\n"
                    "- Make sure your explanation is complete, covering all reasoning steps used to reach the answer.\n"
                    "- Ensure your reasoning is relevant and directly tied to the context, avoiding any unrelated details.\n"
                    "- Keep the explanation clear and logical, with each step following naturally from the previous one.\n"
                    "- Reflect the information in the context faithfully, without adding unsupported assumptions."
                )
            },
            {
                "role": "user",
                "content": (
                    f"CONTEXT:\n{passage}\n\n"
                    f"QUESTION:\n{question}\n\n"
                    f"ANSWER CHOICES:\n1-{options[0]}\n2-{options[1]}\n3-{options[2]}\n4-{options[3]}"
                )
            }
        ]
        
        # Invoke the language model
        result = llm.invoke(messages)
        
        # Save the full generation to a file with UTF-8 encoding
        with open(generation_file, "a", encoding="utf-8") as f:
            json.dump({
                "Passage": passage,
                "Question": question,
                "Options": options,
                "ModelResponse": result.content.strip()
            }, f, ensure_ascii=False)
            f.write("\n")  # Newline for each entry

        logging.info(f"Full generation saved for parsing: {result.content.strip()}")
        return result.content.strip()
    except Exception as e:
        logging.error(f"Error in predict_answer_and_save: {e}")
        return "error"

# Retry function
def make_request_with_retry(func, *args, retries=3, delay=10):
    for attempt in range(retries):
        try:
            return func(*args)
        except ConnectionError as e:
            logging.warning(f"Attempt {attempt + 1} failed: {e}. Retrying in {delay} seconds...")
            time.sleep(delay)
    logging.error("Max retries exceeded")
    raise ConnectionError("Max retries exceeded")

def apply_prediction_and_save(df, model_name, temperature, generation_file="model_generations.json", mode="just_predict", result_name = 'sample'):
    llm = check_api_with_parameters(model_name, temperature)

    results = []

    for index, row in df.iterrows():
        passage = row['flores_passage']
        question = row['question']
        options = [row['mc_answer1'], row['mc_answer2'], row['mc_answer3'], row['mc_answer4']]
        original_answer = row['correct_answer_num']

        logging.info(f"Processing row {index+1}/{len(df)}: {passage[:50]}...")

        # Select the appropriate method
        if mode == "just_predict":
            predicted_answer = make_request_with_retry(predict_answer_and_save, passage, question, options, llm, generation_file)
            time.sleep(10)
        elif mode == "explain_then_predict":
            predicted_answer = explain_then_predict(passage, question, options, llm)
        elif mode == "predict_then_explain":
            predicted_answer = predict_then_explain(passage, question, options, llm)
        else:
            logging.error(f"Invalid mode: {mode}")
            predicted_answer = "error"

        # Save results to the file
        with open(generation_file, "a", encoding="utf-8") as f:
            json.dump({
                "Passage": passage,
                "Question": question,
                "Options": options,
                "OriginalAnswer": original_answer,
                "PredictedAnswer": predicted_answer
            }, f, ensure_ascii=False)
            f.write("\n")

        results.append({
            "Passage": passage,
            "Question": question,
            "Original Answer": original_answer,
            "Predicted Answer": predicted_answer,
            "Option 1": options[0],
            "Option 2": options[1],
            "Option 3": options[2],
            "Option 4": options[3]
        })

        logging.info(f"Row {index+1} processed successfully.")

    # Save final results as DataFrame
    result_df = pd.DataFrame(results)
    output_file_name = result_name + ".csv"
    result_df.to_csv(output_file_name, index=False)
    logging.info("Results saved to {o}".format(o = output_file_name))

    return result_df

# %% [markdown]
# **Chunk the data**

# %%
def split_into_chunks(df, chunk_size):
    """
    Splits a DataFrame into chunks of a specified size.
    
    Parameters:
        df (pd.DataFrame): The DataFrame to split.
        chunk_size (int): The number of rows per chunk.
    
    Returns:
        list: A list of DataFrames, each containing up to `chunk_size` rows.
    """
    chunks = [df.iloc[i:i + chunk_size] for i in range(0, len(df), chunk_size)]
    return chunks

# Example usage
import pandas as pd

# Load your dataset
file_path = 'pes_arab_dataset.csv'
data = pd.read_csv(file_path)

# Split into chunks of 100 rows
chunk_size = 300
chunks = split_into_chunks(data, chunk_size)

# Save each chunk as a separate file
for i, chunk in enumerate(chunks):
    output_file = f"chunk_{i + 1}.csv"
    chunk.to_csv(output_file, index=False)
    print(f"Saved: {output_file}")
# Out:
# Saved: chunk_1.csv
# Saved: chunk_2.csv
# Saved: chunk_3.csv

# %%
chunk_1_data = pd.read_csv('chunk_1.csv')
chunk_2_data = pd.read_csv('chunk_2.csv')
chunk_3_data = pd.read_csv('chunk_3.csv')

# %%
# Apply the prediction
apply_prediction_and_save(chunk_1_data, model_name="command-r-plus", temperature=0.3, result_name='part_1')
# Out:
# 2025-01-24 17:25:15,032 - Processing row 1/300: بسیاری، ریتم‌های فیزیولوژی و رفتار را غالباً به صو...
# 2025-01-24 17:25:15,034 - Starting prediction for passage: بسیاری، ریتم‌های فیزیولوژی و رفتار را غالباً به صو... and question: کدام یک از موارد زیر علیرغم وجود نشانه‌های خارجی ادامه پیدا خواهد کرد؟
# 2025-01-24 17:25:15,789 - HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 403 Forbidden"
# 2025-01-24 17:25:15,789 - Error in predict_answer_and_save: status_code: 403, body: <!doctype html><meta charset="utf-8"><meta name=viewport content="width=device-width, initial-scale=1"><title>403</title>403 Forbidden
# 2025-01-24 17:25:25,792 - Row 1 processed successfully.
# 2025-01-24 17:25:25,793 - Processing row 2/300: جمعیت عبارت است از مجموعه‌ای از موجودات زنده یک گو...
# 2025-01-24 17:25:25,793 - Starting prediction for passage: جمعیت عبارت است از مجموعه‌ای از موجودات زنده یک گو... and question: کدام واژه افرادی را توصیف می‌کند که چندین نوع از خصوصیت فنوتیپی خاصی را نشان می‌دهند؟
# 2025-01-24 17:25:26,449 - HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 403 Forbidden"
# 2025-01-24 17:25:26,451 - Error in predict_answer_and_save: status_code: 403, body: <!doctype html><meta charset="utf-8"><meta name=viewport content="width=device-width, initial-scale=1"><title>403</title>403 Forbidden
# 2025-01-24 17:25:36,455 - Row 2 processed successfully.
# 2025-01-24 17:25:36,456 - Processing row 3/300: جمعیت عبارت است از مجموعه‌ای از موجودات زنده یک گو...
# 2025-01-24 17:25:36,457 - Starting prediction for passage: جمعیت عبارت است از مجموعه‌ای از موجودات زنده یک گو... and question: کدام مورد اصطلاح صحیح برای ارگانیسم‌هایی است که فضای خاصی را اشغال می‌کنند؟
# 2025-01-24 17:25:37,081 - HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 403 Forbidden"
# 2025-01-24 17:25:37,081 - Error in predict_answer_and_save: status_code: 403, body: <!doctype html><meta charset="utf-8"><meta name=viewport content="width=device-width, initial-scale=1"><title>403</title>403 Forbidden
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Apply the prediction
# ----> 2 apply_prediction_and_save(chunk_1_data, model_name="command-r-plus", temperature=0.3, result_name='part_1')
#
# Cell In[14], line 103, in apply_prediction_and_save(df, model_name, temperature, generation_file, mode, result_name)
#     101 if mode == "just_predict":
#     102     predicted_answer = make_request_with_retry(predict_answer_and_save, passage, question, options, llm, generation_file)
# --> 103     time.sleep(10)
#     104 elif mode == "explain_then_predict":
#     105     predicted_answer = explain_then_predict(passage, question, options, llm)
#
# KeyboardInterrupt:

# %%
rs = pd.read_csv('sample_predicted_answers.csv')

# %%
rs.columns
# Out:
# Index(['Passage', 'Question', 'Original Answer', 'Predicted Answer',
#        'Option 1', 'Option 2', 'Option 3', 'Option 4'],
#       dtype='object')

# %% [markdown]
# # Parse Answer

# %%
import re

# Function to clean up and normalize Persian text encoding issues
def clean_text(text):
    if text:
        return text.replace('\u200c', '')  # Replace zero-width non-joiners and any encoding artifacts
    return text

# Updated parsing function with robust handling for variations
def parse_prediction(prediction_text):
    # Clean text first to ensure consistency in encoding
    prediction_text = clean_text(prediction_text)
    
    # Patterns to handle different formats and extract components
    answer_pattern = re.compile(r"<answer>(.*?)</answer>|Answer: (\d)", re.DOTALL)
    explanation_pattern = re.compile(r"<(?:explanation|self-explanation)>(.*?)</(?:explanation|self-explanation)>", re.DOTALL)
    highlight_pattern = re.compile(r"<highlight(?:ed)?>\s*(.*?)\s*</highlight(?:ed)?>", re.DOTALL)
    keywords_pattern = re.compile(r"<keywords>\s*\[(.*?)\]\s*</keywords>", re.DOTALL)

    # Extract answer choice, handle possible formats
    answer_match = answer_pattern.search(prediction_text)
    answer = answer_match.group(1).strip() if answer_match and answer_match.group(1) else None

    # Extract explanation with variations
    explanation_match = explanation_pattern.search(prediction_text)
    explanation = explanation_match.group(1).strip() if explanation_match else None

    # Extract highlighted context with variations
    highlight_match = highlight_pattern.search(prediction_text)
    highlight = highlight_match.group(1).strip() if highlight_match else None

    # Extract keywords as a list
    keywords_match = keywords_pattern.search(prediction_text)
    keywords = [k.strip() for k in keywords_match.group(1).split(",")] if keywords_match else []
    
    return {
        "Parsed Answer": answer,
        "Parsed Explanation": explanation,
        "Parsed Highlighted Context": highlight,
        "Parsed Keywords": keywords
    }

# %%
# Apply the parsing function to the 'Predicted Answer' column and expand into new columns
parsed_columns = rs['Predicted Answer'].apply(parse_prediction).apply(pd.Series)

# Concatenate the parsed columns with the original DataFrame
df = pd.concat([rs, parsed_columns], axis=1)

# %%
df
# Out:
#                                               Passage  \
# 0   بشر هزاران هزار سال از عدسی‌ها برای بزرگ‌نمایی...
# 1   گوارانی‌ها مهم‌ترین گروه بومی ساکن پاراگوئه شر...
# 2   خورشید پوسته‌ای شبیه کره زمین ندارد که بتوانید...
# 3   آن مرد ظاهراً یک خودروی سه‌چرخ مسلح به مواد من...
# 4   ما می توانیم زندگی دوستانه تری را با محیط زیست...
# 5   ورزش‌های زمستانی روی تپه، از جمله اسکی و اسنوب...
# 6   ACMA همچنین نتیجه گرفت که علیرغم اینکه این وید...
# 7   عرفان عبارت است از جستجوی ارتباط، شناخت یا درک...
# 8   محمد عمیقا به امور فراتر از این زندگی دنیوی عل...
# 9   کودکان از زمان کودکی نسبت به نژاد و کلیشه های ...
# 10  به دستور هروستراتوس، معبد آرتمیس در افسوس در 2...
# 11  پیش از این خبرگزاری چینی شینهووا از ربوده شدن ...
# 12  تماشای شکوفه‌های گیلاس (هانامی) از قرن هشتم بخ...
# 13  برای درک تمپلارها باید زمینه ای که موجب ایجاد ...
# 14  قبل از رسیدن اسپانیایی‌ها در قرن 16ام، شیلی شم...
# 15  تیم ملی آفریقای جنوبی تیم ملی راگبی نیوزلند (A...
# 16  به این پدیده pH شیمیایی گفته می‌شود. می‌توانید...
# 17  «هسپرونیکوس الیزابتا» گونه‌ای از تیره «دونده‌خ...
# 18  یک پلیس سابق فیلیپینی با ربودن یک اتوبوس در ما...
# 19  هدف اصلی علم کشف نحوه کار جهان از طریق روش علم...
# 20  وقتی با کسی تماس می‌گیرید که هزاران مایل با شم...
# 21  اکثر معابد یک جشنواره سالانه دارند که از آخر م...
# 22  آنفولانزای مرغی، یا به‌اصطلاح رسمی‌تر آن آنفول...
# 23  در طی سه دهه آخر، علیرغم اینکه چین رسماً دولت ...
# 24  سپاه مهندسی ارتش ایالات متحده تخمین زده که 6 ا...
# 25  پس از وقوع تصادف، «گیبسون» به بیمارستان منتقل ...
# 26  الگوهای فکری همگرا روش‌هایی از حل مسئله هستند ...
# 27  شرکت‌های رسانه‌ای مرتب درباره هدف آن دروغ می‌گ...
# 28  سفر با هواپیما می‌تواند برای افراد از تمام سنی...
# 29  بازیکن منتخب امروز، الکس اوچکین از Washington ...
# 30  تقریباً از همان ابتدا شرایط برای ایتالیایی‌ها ...
# 31  کازینوها معمولاً تلاش فراوان می‌کنند تا زمان و...
# 32  ACMA همچنین نتیجه گرفت که علیرغم اینکه این وید...
# 33  در جلسه ارائه راهبردی نمایشگاه بازی‌های توکیو ...
# 34  او به همراه آن مقامات به شهروندان تگزاس اطمینا...
# 35  بدلیل قرار گرفتن اوکلند بین دو بندرگاه، ساحل‌ه...
# 36  ساز و کار ام‌آرآی بر پایه پدیده‌ای در علم فیزی...
# 37  تیم ملی آفریقای جنوبی تیم ملی راگبی نیوزلند (A...
# 38  براساس گزارش‌ها، یک آپارتمان در خیابان مکبث به...
# 39  پس از صدها ساعت کار، رشته لامپ در نهایت می‌سوز...
# 40  به نظر می‌رسد که بزها ابتدا حدود 10,000 سال پی...
# 41  ستارگان به دلیل انرژی ایجاد شده هنگام ادغام (ی...
# 42  یکی از شایع‌ترین مشکلات هنگام تبدیل کردن فیلم ...
# 43  روش بارز پرواز با صندلی فرست کلاس یا بیزینس ای...
# 44  آدام کوئردن، مدیر منابع مشترک، هنگام گفتگو با ...
# 45  طوفان استوایی دانیل، که چهارمین طوفان در فصل ط...
# 46  در قدیم اینطور بود که وارث تاج و تخت درست پس ا...
# 47  روز چهارشنبه، اتحادیه ملی بسکتبال ایالات متحده...
# 48  پس از آنکه مشخص شد بسیاری از خانواده‌ها به دنب...
# 49  مسافران ممکن است با انواعی از حیوانات موذی موا...
#
#                                              Question  Original Answer  \
# 0   کدام یک از موارد زیر را انسان‌ها در قرن شانزده...                4
# 1   دوران استعمارگری که سه قرن طول کشید توسط کدام ...                4
# 2   با توجه به متن، کدام قسمت از خورشید از زمین قا...                3
# 3    مقامات چه اطلاعاتی درخصوص حمله تأیید کرده بودند؟                2
# 4   با توجه به متن، کدام مورد راه‌حلی قابل اجرا بر...                3
# 5   مطابق با متن، حدود چه زمانی اسکی‌بازی اولین با...                4
# 6   برای اینکه رسانه تحت مقوله محتوای اینترنتی لحا...                2
# 7   با توجه به متن، کدام یک از موارد زیر مورد توجه...                2
# 8   بر اساس متن، غار محمد بیانگر چه چیزی درباره اع...                1
# 9   با توجه به نظریه ارائه شده در متن، برای کودکان...                2
# 10  چه کسی باعث آگاهی ما از آتش افروزی است که معبد...                3
# 11  چه چیز در آخرین گزارش از آژانس خبری شینهووا بی...                2
# 12  چه کسانی میزبان اولین گروه‌های مختص مشاهده شکو...                3
# 13      کدام دوره زمانی قبل از عصر تمپلارها بوده است؟                3
# 14  مطابق متن، کدام‌یک از موارد زیر در سال 1810 رخ...                2
# 15  اسپرینگ باکس مسابقه بعدی خود را در کجا بازی خو...                3
# 16                 چه چیزی از یون‌های هیدروژن حذف شد؟                4
# 17  معنای «Hesperonychus» (هسپرونیکوس) از کدام ویژ...                1
# 18  با توجه به متن، رولاندو مندوزا چه کسی را گروگا...                2
# 19  با توجه به این متن، چه چیزی به هدایت تحقیقات ع...                1
# 20  کدام مورد نشانگر انعکاس تماس‌ از راه دور به پا...                2
# 21  کدام رویداد مرتبط با جشن گرفتن جشنواره‌های معب...                1
# 22  مطابق با متن، کدام‌یک از عبارت‌های زیر آنفولان...                3
# 23  با توجه به متن، کدام یک از عبارات زیر به درستی...                4
# 24  در طول طوفان کاترینا، در Ninth Ward چه اتفاقی ...                3
# 25                          چه کسی در تصادف صدمه دید؟                1
# 26  با توجه به متن، کدام یک تمرکز الگوهای فکری همگ...                2
# 27  مطابق با متن، کدهای منطقه‌ای درواقع به چه چیز ...                2
# 28  تحت چه شرایطی احتمالاً دانستن نحوه کارکرد داخل...                2
# 29  چه کسی گل شصتم فصل را در طول بازی Capitals درم...                3
# 30  چه اتفاقی برای مهندس ارشد ارتش دهم ایتالیا افتاد؟                3
# 31  مطابق با متن، قمارباز هوشمند از چه چیز باید اج...                1
# 32     یافته‌های ACMA در رابطه با Big Brother چه بود؟                1
# 33  بازیکن به چه چیزی نیاز خواهد داشت تا حرکات را ...                4
# 34  مطابق با متن، فرماندار هنگام سخنرانی برای شهرو...                4
# 35  مطابق با متن، شرایط شنا احتمالاً در کجا ایمن‌ت...                3
# 36       چه کسی رزونانس مغناطیسی هسته‌ای را کشف کرد؟                 3
# 37   چه تیم‌هایی در مسابقه الیس پارک بازی خواهند کرد؟                3
# 38                       چه کسی نشت گاز را گزارش داد؟                1
# 39  هنگام تعویض لامپ، لمس کدام یک از موارد زیر می‌...                3
# 40  کدام یک از موارد زیر دلیلی بر نگهداری بز در فر...                3
# 41  یک راکتور همجوشی کارامد کدام یک از موارد زیر ر...                4
# 42     چرا کناره تصاویر در تلویزیون برش خورده می‌شود؟                2
# 43  مطابق با متن، هنگام رزرو کلاس‌های بلیط مشخص، ج...                3
# 44  کدام‌یک از موارد زیر دلیل سرخوردگی آدام کوئردن...                1
# 45  چرا اندازه‌گیری تأثیر احتمالی طوفان استوایی دا...                3
# 46  با توجه به متن، کدام مورد برای وارث تاج و تخت ...                2
# 47             NBA تصمیم به تعلیق کدام مورد زیر گرفت؟                1
# 48  مطابق با آنچه در متن بیان شد، کارولین ویلسون ق...                3
# 49  انجام کدام‌یک از موارد زیر احتمالاً از یک حیوا...                4
#
#                                      Predicted Answer  \
# 0   <answer>4</answer>\n\n<explanation>در متن گفته...
# 1   <answer>4</answer>\n\n<explanation>گفته شده اس...
# 2   <answer>3</answer>\n\n<explanation>در متن گفته...
# 3   <answer>2</answer>\n\n<explanation>در متن گفته...
# 4   <answer>3</answer>\n\n<explanation>در متن اشار...
# 5   <answer>4</answer>\n\n<explanation>متن اشاره م...
# 6   <answer>2</answer>\n\n<explanation>در متن گفته...
# 7   <answer>2</answer>\n\n<explanation>عرفان به دن...
# 8   <answer>1</answer>\n\n<explanation>غار حرا، مک...
# 9   <answer>1</answer>\n\n<explanation>با توجه به ...
# 10  <answer>3</answer>\n\n<explanation>در متن گفته...
# 11  <answer>2</answer>\n\n<explanation>گزارش اولیه...
# 12  <answer>3-امپراطور ژاپن</answer>\n\n<explanati...
# 13  <answer>3</answer>\n\n<explanation>در متن گفته...
# 14  <answer>2</answer>\n\n<explanation>متن اشاره م...
# 15  <answer>3</answer>\n\n<explanation>\nدر متن گف...
# 16  <answer>1</answer>\n\n<explanation>در متن گفته...
# 17  <answer>1</answer>\n\n<explanation>نام "هسپرون...
# 18  <answer>4</answer>\n\n<explanation>متن اشاره م...
# 19  <answer>1-روش علمی به تنهایی</answer>\n\n<expl...
# 20  <answer>2</answer>\n\n<explanation>در متن گفته...
# 21  <answer>1</answer>\n\n<explanation>جشنواره‌های...
# 22  <answer>3</answer>\n\n<explanation>در متن گفته...
# 23  <answer>4</answer>\n\n<explanation>متن می‌گوید...
# 24  <answer>3</answer>\n\n<explanation>در متن گفته...
# 25  <answer>1</answer>\n\n<explanation>در متن گفته...
# 26  <answer>1</answer>\n\n<explanation>در متن ذکر ...
# 27  <answer>2</answer>\n\n<explanation>در متن گفته...
# 28  <answer>2</answer>\n\n<explanation>در متن گفته...
# 29  <answer>3</answer>\n\n<explanation>در متن گفته...
# 30  <answer>3</answer>\n\n<explanation>در متن گفته...
# 31  <answer>1</answer>\n\n<explanation>متن اشاره م...
# 32  <answer>1</answer>\n\n<explanation>ACMA نتیجه ...
# 33  <answer>4</answer>\n\n<explanation>در متن گفته...
# 34  <answer>1</answer>\n\n<explanation>فرماندار تگ...
# 35  <answer>2</answer>\n\n<explanation>در متن گفته...
# 36  <answer>3</answer>\n\n<explanation>فلیکس بلوچ ...
# 37  <answer>3</answer>\n\n<explanation>\nدر متن گف...
# 38  <answer>1</answer>\n\n<explanation>در متن گزار...
# 39  <answer>3</answer>\n\n<explanation>در متن گفته...
# 40  <answer>2</answer>\n\n<explanation>در متن اشار...
# 41  <answer>4</answer>\n\n<explanation>در متن گفته...
# 42  <answer>2</answer>\n\n<explanation>در متن گفته...
# 43  <answer>3</answer>\n\n<explanation>\nدر متن گف...
# 44  <answer>1</answer>\n\n<explanation>آدام کوردن ...
# 45  <answer>3</answer>\n\n<explanation>در متن گفته...
# 46  <answer>2</answer>\n\n<explanation>در متن گفته...
# 47  <answer>1</answer>\n\n<explanation>در متن گفته...
# 48  <answer>3</answer>\n\n<explanation>در متن گفته...
# 49  <answer>4</answer>\n\n<explanation>حیوانات موذ...
#
#                                              Option 1  \
# 0                                  استفاده از عدسی‌ها
# 1                                            پاراگوئه
# 2                                               پوسته
# 3                                      هویت هم‌دست‌ها
# 4             تحریم انتخاب‌های سبک زندگی مصرف‌گرایانه
# 5                                           قرن هجدهم
# 6                        باید از طریق اینترنت پخش شود
# 7                          جستجوی شهود به واقعیت الهی
# 8                 او برای آرامش و انزوا ارزش قائل بود
# 9   کودک سعی می‌کند از درگیر شدن در رفتارهای تهدید...
# 10                                            افسسیان
# 11              هواپیما یک تهدید بمب‌گذاری دریافت کرد
# 12                                       امپراطور چین
# 13                                     قرون وسطی اخری
# 14                              دولت مرکزی وجود نداشت
# 15                                           استرالیا
# 16                                             پروتون
# 17                                           پنجه(ها)
# 18                                           گردشگران
# 19                                 روش علمی به تنهایی
# 20                                          تلسکوپ‌ها
# 21                                           تولد فیل
# 22     فقط کارکنان مرغداری به آنفولانزا مبتلا شده‌اند
# 23  اقتصاد چین از زمان انجام اصلاحات به طور تصاعدی...
# 24                            آب سیل 100 فوت عرض داشت
# 25                                           «گیبسون»
# 26              درک اینکه تنها یک پاسخ صحیح وجود دارد
# 27                                      کپی کردن دیسک
# 28                اگر مسافر از ترس خود خجالت‌زده باشد
# 29                                       ماریو لمیوکس
# 30                  در Fort Capuzzo به اسارت گرفته شد
# 31                                   نوشیدن الکل زیاد
# 32                         قوانین سانسور نقض نشده بود
# 33  اطمینان از اینکه سنسورهای کنترلر نزدیک کنسول ق...
# 34                           سیستم به‌خوبی کار می‌کند
# 35                                            دونپورت
# 36                                              پورسل
# 37                              All Blacks و استرالیا
# 38                        یکی از همسایگان در آپارتمان
# 39                                               رشته
# 40             امکان دسترسی به گوشت را فراهم می‌کردند
# 41                                            هیدروژن
# 42                     برای ایجاد امکان زیرنویس نوشتن
# 43                                    پروازهای مستقیم
# 44                خط‌مشی جدید سایت درخصوص محتوای جنسی
# 45     پیش‌بینی می‌شود این طوفان به یک توفند شدت یابد
# 46                                    دریافت مدرک 2:2
# 47                                        فصل بسکتبال
# 48                            مرکز حقوق عام خلیج شرقی
# 49                                    سبب جوش زدن شدن
#
#                                              Option 2  \
# 0                                     بزرگنمایی اشیاء
# 1                                            Guaycurú
# 2                                              پلاسما
# 3                                         قومیت مظنون
# 4                                              کنشگری
# 5                               5000 سال قبل از میلاد
# 6              باید به صورت فیزیکی در سروری قرار گیرد
# 7             طلب بینش از طریق تجربیات مشترک و همگانی
# 8                    صدای بیرون به تأمل او کمک می‌کرد
# 9   احتمال بیشتری وجود دارد که کودک درگیر رفتارهای...
# 10                                           الکساندر
# 11                        هواپیما در اورومچی فرود آمد
# 12                                        اشراف ژاپنی
# 13                                           قرن 12ام
# 14                           شیلی بر اسپانیا پیروز شد
# 15                                           راستنبرگ
# 16                                                 pH
# 17                                   بدن پوشیده از پر
# 18                                               پلیس
# 19                                      انجام مشاهدات
# 20                                        ماهواره‌ها
# 21                                        سالگرد معبد
# 22  موارد بیشتری در انسان‌ها نسبت به پرنده‌ها گزار...
# 23  چین بازار بزرگتری برای صادرات خودرو نسبت به ای...
# 24             آب با ارتفاع تا کمر از روی آب‌بند گذشت
# 25                                        کارگر گاراژ
# 26                                         وقت گذاشتن
# 27                                        کنترل بازار
# 28  اگر نفرت او از پرواز ناشی از ترس از ناشناخته‌ه...
# 29                                       جارومیر جاگر
# 30                                    در طبرق کشته شد
# 31                                      قبول هر مشوقی
# 32  مشخص شد که رسانه در وب‌سایت Big Brother ذخیره ...
# 33                             مثلثی کردن موقعیت آنها
# 34   کارهایی برای حفاظت از ایمنی عموم درحال انجام است
# 35                                   منطقه نورث هاربر
# 36                                           دامادیان
# 37                            نیوزلند و آفریقای جنوبی
# 38                   فردی که در آپارتمان زندگی می‌کرد
# 39                                          کلید لامپ
# 40                  به کوتاه کردن چمن‌ها کمک می‌کردند
# 41                                           ستاره‌ها
# 42         برای اینکه تصویر با کل صفحه تطبیق پیدا کند
# 43                                        کلاس بیزینس
# 44                                        حذف هنر ولز
# 45  دانشمندان درباره پایداری سرعت وزش بادهای طوفان...
# 46               رها کردن دانشگاه برای رفتن به سربازی
# 47                              یک بازیکن از یوتا جاز
# 48                                        پلیس اوکلند
# 49                                   حساسیت‌های پوستی
#
#                                              Option 3  \
# 0                                        ساخت عدسی‌ها
# 1                                          گورانی‌ها
# 2                                             فوتوسفر
# 3                                         انگیزه حمله
# 4                                    یافتن ریشه مسئله
# 5                                                1861
# 6                      نمی‌تواند روی وبسایت ذخیره شود
# 7                      تأکید بر حالت سعادتمند خودآگاه
# 8              به زمان خیلی کمی برای تنهایی نیاز داشت
# 9        کودک در موقعیت‌های اجتماعی کناره‌گیری می‌کند
# 10                                            استرابو
# 11               مسیر هواپیما به سمت افغانستان عوض شد
# 12                                      امپراطور ژاپن
# 13                                     قرون وسطی بالا
# 14                   جنگ‌های ناپلئونی درحال انجام بود
# 15                                         ژوهانسبورگ
# 16                                               قلیا
# 17                                               پاها
# 18                                             کودکان
# 19                                 حذف فرضیه‌های ممکن
# 20                                            چراغ‌ها
# 21                                   زادروز خدای حاکم
# 22        تماشاکنندگان پرندگان در خطر مبتلا شدن هستند
# 23  چین در نهایت توانست GDP بزرگتری نسبت به ایالات...
# 24                      آب‌های سیل 20 فوت ارتفاع داشت
# 25                                             کودکان
# 26                                      شناسایی حقایق
# 27                             جلوگیری از نشر غیرمجاز
# 28            اگر مسافر مخالف هر نوع وسیله نقلیه باشد
# 29                                        الکس اوچکین
# 30               توسط بریتانیایی‌ها به اسارت گرفته شد
# 31                                         بررسی ساعت
# 32                          قوانین سانسور نقض شده بود
# 33                   قرار دادن سنسورها نزدیک تلویزیون
# 34  آنها ابزار لازم را برای رویارویی با این چالش د...
# 35                                       اوکلند مرکزی
# 36                                       بلوچ و پورسل
# 37                           آفریقای جنوبی و استرالیا
# 38                               از مقام‌های شرکت گاز
# 39                                          پایه لامپ
# 40                                نقش همراه را داشتند
# 41                                             اتم‌ها
# 42       برای ایجاد امکان تبدیل ساده به فرمت‌های دیگر
# 43                                           تخفیف‌ها
# 44                                       عدم توجه ولز
# 45                      طوفان خیلی از خشکی فاصله دارد
# 46                                       مطالعه تاریخ
# 47              هر بازیکنی که تست کووید-19 او مثبت شد
# 48                                                OHA
# 49                                       انتقال عفونت
#
#                                              Option 4         Parsed Answer  \
# 0                                         ساخت تلسکوپ                     4
# 1                                    فاتحان اسپانیایی                     4
# 2                                                مرکز                     3
# 3                            نام و نام خانوادگی مظنون                     2
# 4                    تبدیل شدن به متحد جنبش محیط زیست                     3
# 5                                           قرن هفدهم                     4
# 6                            باید توسط ACMA تأیید شود                     2
# 7                              طلب درک آگاهانه الوهیت                     2
# 8                  نگران این بود که دیده یا شنیده شود                     1
# 9   کودک از تعامل با سایر اقلیت‌های نژادی امتناع خ...                     1
# 10                                             آرتمیس                     3
# 11                         هواپیما در قندهار فرود آمد                     2
# 12                                         اشراف چینی       3-امپراطور ژاپن
# 13                                           قرن 13ام                     3
# 14                             شیلی اعلام استقلال کرد                     2
# 15                                            نیوزلند                     3
# 16                                         الکترون‌ها                     1
# 17                                              منقار                     1
# 18                                             عکاسان                     4
# 19                                     انجام آزمایشات  1-روش علمی به تنهایی
# 20                                            موشک‌ها                     2
# 21                        رویدادهای مهم مربوط به معبد                     1
# 22   تمام موارد گزارش شده در انسان‌ها مرگبار بوده است                     3
# 23       چین هرگز بیشتر از آلمان خودرو صادر نکرده است                     4
# 24        6 اینچ بارندگی از آب‌بند آسیب‌دیده نفوذ کرد                     3
# 25                                      راننده کامیون                     1
# 26                                   جمع‌آوری اطلاعات                     1
# 27                               کپی‌برداری غیرقانونی                     2
# 28  اگر ریشه اضطراب او از رخدادهای ترومای نامربوط ...                     2
# 29                                     نیکلاس بکستروم                     3
# 30                                با آتش خودی کشته شد                     3
# 31                      پرسیدن درباره نزدیکترین خروجی                     1
# 32  مشخص شد که محتوا به صورت فیزیکی در یک سرور قرا...                     1
# 33                            حرکت دادن کنترلر در هوا                     4
# 34                                این پرونده جدی نیست                     1
# 35                                            لانگ‌بی                     2
# 36                                    بلوچ و دامادیان                     3
# 37                          اسپرینگ باکس و All Blacks                     3
# 38                                      مدیر آپارتمان                     1
# 39                                               سیم                      3
# 40                    دسترسی به شیر را فراهم می‌کردند                     2
# 41                                              انرژی                     4
# 42  برای بیش از اندازه نزدیک به پایین برش خوردن زی...                     2
# 43                                          فرست کلاس                     3
# 44                        دروغ‌ها درباره دلیل حذف هنر                     1
# 45               طوفان فاصله خیلی زیادی از میامی دارد                     3
# 46             تحصیل در دانشگاه پیش از رفتن به سربازی                     2
# 47                               تیم بسکتبال یوتا جاز                     1
# 48                                    باغ‌های لاک‌وود                     3
# 49                             سبب جراحت‌های شدید شدن                     4
#
#                                    Parsed Explanation  \
# 0   در متن گفته شده که اولین تلسکوپهای واقعی در قر...
# 1   گفته شده است که پاراگوئه در قرن 16ام پس از برخ...
# 2   در متن گفته شده که وقتی به خورشید نگاه میکنیم،...
# 3   در متن گفته شده که مقامات میدانند مرد مظنون به...
# 4   در متن اشاره شده است که برای یافتن راهحلی بلند...
# 5   متن اشاره میکند که ورزش اسکی روی تپه «حداقل» ب...
# 6   در متن گفته میشود که محتوا برای اینکه جزء "محت...
# 7   عرفان به دنبال تجربه مستقیم و شخصی از واقعیت ا...
# 8   غار حرا، مکانی بود که محمد برای تأمل و تفکر ان...
# 9   با توجه به نظریه ارائه شده در متن، کودکان بر ا...
# 10  در متن گفته شده که مورخ یونانی استرابو بود که ...
# 11  گزارش اولیه شینهووا تنها به ربوده شدن هواپیما ...
# 12  در متن گفته میشود که "در ژاپن، نخستین مراسم شک...
# 13  در متن گفته شده که "قرون وسطی بالا بعد از قرون...
# 14  متن اشاره میکند که شیلی در سال 1810 اعلام استق...
# 15  در متن گفته میشود که مسابقه بعدی سری در ژوهانس...
# 16  در متن گفته میشود که «یونهای هیدروژن پروتونهای...
# 17  نام "هسپرونیکوس" به معنی "پنجه غربی" است که اش...
# 18  متن اشاره میکند که رونالدو مندوزا، گردشگران هن...
# 19  در متن گفته شده که روش علمی اکثر تحقیقات علمی ...
# 20  در متن گفته شده که ماهوارهها تماسهای تلفنی را ...
# 21  جشنوارههای معبد معمولاً با رویدادهایی مانند جش...
# 22  در متن گفته شده که آنفولانزای پرندگان میتواند ...
# 23  متن میگوید که چین برای اولین بار خودروهای بیشت...
# 24  در متن گفته شده که در زمان توفان کاترینا، بخش ...
# 25  در متن گفته شده که «گیبسون» پس از تصادف به بیم...
# 26  در متن ذکر شده که تمرکز الگوهای فکری همگرا بر ...
# 27  در متن گفته میشود که هدف واقعی از استفاده از ک...
# 28  در متن گفته میشود که دانستن چگونگی کار کردن هو...
# 29  در متن گفته شده که «الکس اوچکین» در آن بازی دو...
# 30  در متن گفته شده که انگلیسیها مهندس ارشد ارتش د...
# 31  متن اشاره میکند که مستی قضاوت را مختل میکند و ...
# 32  ACMA نتیجه گرفت که Big Brother قوانین سانسور م...
# 33  در متن گفته شده که دسته جدید کنسول Nintendo Re...
# 34  فرماندار تگزاس به شهروندان اطمینان داد که اقدا...
# 35  در متن گفته شده است که سواحل نورث شور که در من...
# 36  فلیکس بلوچ و ادوارد پورسل پدیده رزونانس مغناطی...
# 37  در متن گفته شده که در مسابقه نهایی سری در ورزش...
# 38  در متن گزارش آمده است که "یکی از همسایهها دربا...
# 39  در متن گفته میشود که الکتریسیتهای که به داخل س...
# 40  در متن اشاره شده که بزها برای دسترسی به شیر، پ...
# 41  در متن گفته میشود که ستارگان با ادغام اتمهای ه...
# 42  در متن گفته شده که تلویزیونها طوری ساخته شدهان...
# 43  در متن گفته میشود که «جستجوی تخفیف برای صندلیه...
# 44  آدام کوردن از دروغهای ولز و حذف هنرش ابراز نار...
# 45  در متن گفته شده که طوفان دانیل در اقیانوس اطلس...
# 46  در متن گفته شده است که در گذشته وارث تاج و تخت...
# 47  در متن گفته شده که اتحادیه ملی بسکتبال (NBA) ف...
# 48  در متن گفته شده کارولین ویلسون از OHA پول پیش ...
# 49  حیوانات موذی ممکن است باعث انتقال عفونت شوند، ...
#
#                            Parsed Highlighted Context  \
# 0   بشر هزاران هزار سال از عدسیها برای بزرگنمایی ا...
# 1   در قرن 16، پاراگوئه که قبلاً «استان غول پیکر ه...
# 2   وقتی به خورشید نگاه میکنیم قسمت بیرونی که میبی...
# 3   اگرچه آنها میدانند كه او عضو گروه قومی اویغور است
# 4   «باید ریشه مشکلات را بیابیم و باید آنها را غیر...
# 5       ورزش اسکی روی تپه حداقل به قرن 17 ام برمیگردد
# 6   قانون خدمات پخش مقررات محتوای اینترنتی را مشخص...
# 7   عرفان عبارت است از جستجوی ارتباط، شناخت یا درک...
# 8   خود غار که طی اعصار سالم مانده است بیانگر تصور...
# 9   کودکان از زمان کودکی نسبت به نژاد و کلیشه های ...
# 10  مورخ یونانی استرابو بعداً به نام آن اشاره كرده...
# 11  پیش از این خبرگزاری چینی شینهووا از ربوده شدن ...
# 12  در ژاپن، نخستین مراسم شکوفه گیلاس توسط امپراتو...
# 13           قرون وسطی بالا بعد از قرون وسطی شکل گرفت
# 14  اگرچه کشور شیلی در 1810 اعلام استقلال کرد، پیر...
# 15  هفته بعد مسابقه نهایی این سری در ورزشگاه الیس ...
# 16  یونهای هیدروژن پروتونهایی هستند که الکترون از ...
# 17  نام «هسپرونیکوس» به معنی «پنجه غربی» است که به...
# 18  رونالدو مندوزا، گردشگران هنگ کنگی را گروگان گر...
# 19  هدف اصلی علم کشف نحوه کار جهان از طریق روش علم...
# 20  وقتی با کسی تماس میگیرید که هزاران مایل با شما...
# 21  جشنوارههای معبد کرالا با داشتن موکبهای منظم از...
# 22  آنفولانزای پرندگان میتواند هم پرندگان و هم پست...
# 23  سال گذشته چین برای اولین بار خودروهای بیشتری ا...
# 24  در زمان توفان کاترینا، بخش «ناینت وارد» شاهد س...
# 25  «گیبسون» پس از وقوع تصادف به بیمارستان منتقل ش...
# 26  تمرکز این طرز فکر بر روی سرعت، منطق و دقت است،...
# 27  شرکتهای رسانهای ادعا میکنند که استفاده از کدها...
# 28  سفر با هواپیما میتواند برای افرادی که قبلاً پر...
# 29               دومین گل آن شب او شصتمین گل فصلش بود
# 30  در کمین شرق بردیا، انگلیسیها مهندس ارشد ارتش د...
# 31  مستی قضاوت را مختل میکند و همه قماربازان خوب ا...
# 32  ACMA نتیجه گرفت که Big Brother قوانین سانسور م...
# 33  «این به بازیکنان امکان خواهد داد تا اقدامات و ...
# 34  «این پرونده جدی است. مطمئن باشید سیستم ما آنطو...
# 35  آنها تقریباً همه سواحل شنی هستند که شنا در آنه...
# 36  فلیکس بلوچ (فعال در دانشگاه استانفورد) و ادوار...
# 37  هفته بعد مسابقه نهایی این سری در ورزشگاه الیس ...
# 38           یکی از همسایهها درباره نشت گاز تماس گرفت
# 39  الکتریسیتهای که به داخل سوکت در محل قرارگیری ق...
# 40  فرهنگهای کهن و قبایل شروع به نگهداری از آنها ب...
# 41  ستارگان با ادغام اتمهای هیدروژن، انرژی تولید م...
# 42  اکثر تلویزیونها طوری ساخته شدهاست که مورد پسند...
# 43  «جستجوی تخفیف برای صندلیهای بیزینس و فرست کلاس...
# 44  آدام کوئردن، مدیر منابع مشترک، از دروغهای ولز ...
# 45  طوفان استوایی دانیل در اقیانوس اطلس شرقی شکل گ...
# 46  در قدیم اینطور بود که وارث تاج و تخت درست پس ا...
# 47  اتحادیه ملی بسکتبال ایالات متحده (NBA) فصل بسک...
# 48  وقتی اجارهنشینها شروع به درمیان گذاشتن چیزی کر...
# 49  خود بیماریهای عفونی یا حیوانات خطرناکی که میتو...
#
#                                       Parsed Keywords
# 0   ['تلسکوپ', 'عدسی', 'بزرگنمایی', 'قرن ۱۶', 'ارو...
# 1   ['گوارانی', 'بومی', 'پاراگوئه', 'شکارچیان', 'ک...
# 2                               ['خورشید', 'فوتوسفر']
# 3   ['مرد مظنون', 'بمبگذاری', 'قومیت', 'اویغور', '...
# 4   ['محیط زیست', 'درمان حمایتی', 'پیشرفتهای علمی'...
# 5   ["ورزشهای زمستانی", "اسکی", "اسنوبورد", "تپه",...
# 6   ['قانون خدمات پخش', 'محتوای اینترنتی', 'سرور',...
# 7   ['عرفان', 'تجربه مستقیم', 'واقعیت الهی', 'بینش...
# 8   ["غار حرا"، "تأمل"، "کوه نور"، "انزوا"، "آرامش...
# 9   ["کودک", "نژاد", "کلیشه", "رفتار", "اقلیت", "م...
# 10  ["هروستراتوس"، "معبد آرتمیس"، "افسوس"، "آتشسوز...
# 11  ['ربوده شدن هواپیما', 'تهدید بمبگذاری', 'تغییر...
# 12  ["ژاپن"، "امپراطور"، "مراسم شکوفه گیلاس"، "میز...
# 13  ["تمپلارها"، "قرون وسطی"، "قرون وسطی بالا"، "ق...
# 14  ['شیلی', 'اعلام استقلال', 'پیروزی بر اسپانیا',...
# 15  ['راگبی', 'ورزشگاه', 'آفریقای جنوبی', 'استرالی...
# 16  ['pH', 'شیمیایی', 'شاخص', 'آب کلم قرمز', 'اسید...
# 17        ['هسپرونیکوس', 'پنجه', 'غربی', 'پنجه_بزرگ']
# 18  ["گروگان"، "رونالدو مندوزا"، "گردشگران هنگ کنگ...
# 19  ["روش علمی"، "تحقیقات علمی"، "آزمایش"، "مشاهدا...
# 20  ['تماس تلفنی', 'فاصله', 'ماهواره', 'فضا', 'انع...
# 21  ["جشنواره سالانه"، "معبد"، "جشن سالگرد"، "زادر...
# 22  ["آنفولانزای پرندگان"، "پرندگان"، "پستانداران"...
# 23  ["چین"، "اقتصاد"، "صادرات خودرو"، "آلمان"، "با...
# 24  ['سپاه مهندسی ارتش', 'ایالات متحده', 'باران', ...
# 25  ['تصادف', 'گیبسون', 'بیمارستان', 'درگذشت', 'را...
# 26  ['الگوهای فکری همگرا', 'حل مسئله', 'ادغام ایده...
# 27  ["کدهای منطقهای"، "کنترل بازار"، "پول بیشتر"، ...
# 28  ["سفر با هواپیما"، "ترس"، "ناشناختهها"، "عدم ک...
# 29                    ["الکس اوچکین"، "گل"، "شصتمین"]
# 30  ['ایتالیا', 'جنگ', 'لیبی', 'بریتانیا', 'به اسا...
# 31  ['کازینو', 'مستی', 'قضاوت', 'هوشیاری', 'قمارباز']
# 32  ['ACMA'، 'قوانین سانسور'، 'محتوای آنلاین'، 'وب...
# 33  ["دسته"، "کنترلر"، "سنسور"، "تلویزیون"، "فضای ...
# 34  ["تضمین", "ایمنی عمومی", "سیستم", "پرونده", "ج...
# 35  ["اوکلند"، "بندرگاه"، "ساحل"، "نورث شور"، "نور...
# 36  ["کشف"، "رزونانس مغناطیسی هستهای"، "بلوچ"، "پو...
# 37  ['آفریقای جنوبی', 'استرالیا', 'الیس پارک', 'را...
# 38         ["نشت گاز"، "همسایه"، "آپارتمان"، "گزارش"]
# 39  ['لامپ', 'حباب', 'الکتریسیته', 'شوک', 'سوکت', ...
# 40  ['بز', 'اهلی', 'کوههای زاگرس', 'ایران', 'فرهنگ...
# 41  ['راکتور همجوشی', 'انرژی', 'اتم', 'هیدروژن', '...
# 42  ["تلویزیون", "برش", "تصویر", "صفحه", "مردم", "...
# 43  ['پرواز', 'بیزینس', 'فرست کلاس', 'تخفیف', 'بیف...
# 44  ["آدام کوئردن"، "سرخوردگی"، "دروغ"، "حذف هنر"،...
# 45  ["طوفان استوایی دانیل"، "اقیانوس اطلس شرقی"، "...
# 46        ["وارث تاج و تخت"، "سربازی"، "اتمام تحصیل"]
# 47  ["اتحادیه ملی بسکتبال"، "فصل بسکتبال"، "کووید-...
# 48                                                 []
# 49  ['حیوانات موذی', 'خراب کردن غذا', 'آزار و اذیت...

# %%
from IPython.display import display, HTML

# Function to display each result with RTL formatting for Passage and Question
def display_result(row):
    html = f"""
    <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
        <p><strong>Row {row.name + 1}:</strong></p>
        <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>{row['Passage']}</span></p>
        <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>{row['Question']}</span></p>
        <p><strong>Original Answer:</strong> {row['Original Answer']}</p>
        <p><strong>Predicted Answer:</strong> {row['Parsed Answer']}</p>
        <p><strong>Options:</strong>
            <br>1: {row['Option 1']}
            <br>2: {row['Option 2']}
            <br>3: {row['Option 3']}
            <br>4: {row['Option 4']}
        </p>
        <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>{row['Parsed Explanation']}</span></p>
        <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>{row['Parsed Highlighted Context']}</span></p>
        <p><strong>Keywords:</strong> {row['Parsed Keywords']}</p>
    </div>
    """
    display(HTML(html))

# Apply the display function to all rows in the DataFrame
for _, row in df.iterrows():
    display_result(row)
# Out:
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 1:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>بشر هزاران هزار سال از عدسی‌ها برای بزرگ‌نمایی استفاده می‌کرده است. با این حال، اولین تلسکوپ های واقعی در اواخر قرن 16 در اروپا ساخته شدند. در این تلسکوپ از ترکیب دو عدسی استفده شده است تا اجسام دور را هم نزدیکتر و هم بزرگتر نشان دهد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>کدام یک از موارد زیر را انسان‌ها در قرن شانزدهم شروع کردند؟</span></p>
#         <p><strong>Original Answer:</strong> 4</p>
#         <p><strong>Predicted Answer:</strong> 4</p>
#         <p><strong>Options:</strong>
#             <br>1: استفاده از عدسی‌ها
#             <br>2: بزرگنمایی اشیاء
#             <br>3: ساخت عدسی‌ها
#             <br>4: ساخت تلسکوپ
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که اولین تلسکوپهای واقعی در قرن ۱۶ در اروپا ساخته شدند. پس تنها گزینهای که با اطلاعات متن مطابقت دارد، ساخت تلسکوپ است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>بشر هزاران هزار سال از عدسیها برای بزرگنمایی استفاده میکرده است. با این حال، اولین تلسکوپهای واقعی در اواخر قرن ۱۶ در اروپا ساخته شدند.</span></p>
#         <p><strong>Keywords:</strong> ["'تلسکوپ'", "'عدسی'", "'بزرگنمایی'", "'قرن ۱۶'", "'اروپا'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 2:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>گوارانی‌ها مهم‌ترین گروه بومی ساکن پاراگوئه شرقی کنونی بودند که به شکل شکارچیان نیمه کوچ‌نشین زندگی می‌کردند و به کشاورزی معیشتی نیز می‌پرداختند. منطقه چاکو محل اقامت گروه‌های دیگر قبایل بومی مانند Guaycurú و Payaguá بود که با شکار، جمع آوری و ماهیگیری زندگی خود را می‌گذراندند. در قرن 16، پاراگوئه که قبلاً «استان غول پیکر هند» خوانده می شد، در نتیجه برخورد فاتحان اسپانیایی با گروه های بومی متولد شد. اسپانیایی‌ها دوره استعماری را شروع کردند که سه قرن طول کشید. پاراگوئه از زمان تأسیس آسانسیون در سال 1537، توانسته است بسیاری از خصوصیات و شخصیت‌های بومی خود را حفظ کند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>دوران استعمارگری که سه قرن طول کشید توسط کدام گروه شروع شد؟</span></p>
#         <p><strong>Original Answer:</strong> 4</p>
#         <p><strong>Predicted Answer:</strong> 4</p>
#         <p><strong>Options:</strong>
#             <br>1: پاراگوئه
#             <br>2: Guaycurú
#             <br>3: گورانی‌ها
#             <br>4: فاتحان اسپانیایی
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>گفته شده است که پاراگوئه در قرن 16ام پس از برخورد فاتحان اسپانیایی با گروههای بومی متولد شد. این برخورد آغاز دورهای استعماری سه قرن بود. بنابراین، پاسخ این است که دوران استعماری توسط فاتحان اسپانیایی آغاز شد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>در قرن 16، پاراگوئه که قبلاً «استان غول پیکر هند» خوانده می شد، در نتیجه برخورد فاتحان اسپانیایی با گروه های بومی متولد شد. اسپانیاییها دوره استعماری را شروع کردند که سه قرن طول کشید.</span></p>
#         <p><strong>Keywords:</strong> ["'گوارانی'", "'بومی'", "'پاراگوئه'", "'شکارچیان'", "'کشاورزی'", "'چاکو'", "'Guaycurú'", "'Payaguá'", "'فاتحان'", "'اسپانیایی'", "'استعماری'", "'آسانسیون'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 3:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>خورشید پوسته‌ای شبیه کره زمین ندارد که بتوانید روی آن بایستید. کل خورشید از گازها، آتش و پلاسما ساخته شده است. هرچه از مرکز خورشید دورتر شوید، این گاز رقیق‌تر می‌شود. وقتی به خورشید نگاه می‌کنیم قسمت بیرونی که می‌بینیم فوتوسفر گفته می‌شود که به معنی «توپ نور» است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به متن، کدام قسمت از خورشید از زمین قابل مشاهده است؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: پوسته
#             <br>2: پلاسما
#             <br>3: فوتوسفر
#             <br>4: مرکز
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که وقتی به خورشید نگاه میکنیم، قسمت بیرونی که مشاهده میکنیم «فوتوسفر» نام دارد. بنابراین قسمت قابل مشاهده خورشید، فوتوسفر است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>وقتی به خورشید نگاه میکنیم قسمت بیرونی که میبینیم فوتوسفر گفته میشود</span></p>
#         <p><strong>Keywords:</strong> ["'خورشید'", "'فوتوسفر'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 4:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>آن مرد ظاهراً یک خودروی سه‌چرخ مسلح به مواد منفجره را به داخل جمعیت هدایت کرده بود. مرد مظنون به انفجار بمب، پس از تحمل جراحات ناشی از انفجار، بازداشت شد. اگرچه آنها می‌دانند كه او عضو گروه قومی اویغور است، نام وی هنوز برای مقامات ناشناخته است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>مقامات چه اطلاعاتی درخصوص حمله تأیید کرده بودند؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: هویت هم‌دست‌ها
#             <br>2: قومیت مظنون
#             <br>3: انگیزه حمله
#             <br>4: نام و نام خانوادگی مظنون
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که مقامات میدانند مرد مظنون به بمبگذاری عضو گروه قومی اویغور است، بنابراین تنها اطلاعاتی که مقامات در خصوص این حمله تأیید کردهاند، قومیت مظنون است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>اگرچه آنها میدانند كه او عضو گروه قومی اویغور است</span></p>
#         <p><strong>Keywords:</strong> ["'مرد مظنون'", "'بمبگذاری'", "'قومیت'", "'اویغور'", "'مقامات'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 5:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>ما می توانیم زندگی دوستانه تری را با محیط زیست آغاز کنیم، می توانیم به جنبش محیط زیست بپیوندیم و حتی می توانیم برای اینکه تا حدودی آلام آینده را کاهش دهیم، فعال محیط زیست شویم. این دقیقاً مانند بسیاری از موارد درمان حمایتی است. با این وجود، اگر تنها به دنبال یک راه‌حل موقت نباشیم، باید ریشه مشکلات را بیابیم و باید آن‌ها را غیرفعال کنیم. پرواضح است که دنیا به‌خاطر پیشرفت‌های علمی و فناوری بشر تغییر کرده و مشکلات به دلیل جمعیت بسیار زیاد و شیوه زندگی عجیب و غریب بشر، بیشتر شده است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به متن، کدام مورد راه‌حلی قابل اجرا برای مسائل زیست‌محیطی در بلندمدت محسوب می‌شود؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: تحریم انتخاب‌های سبک زندگی مصرف‌گرایانه
#             <br>2: کنشگری
#             <br>3: یافتن ریشه مسئله
#             <br>4: تبدیل شدن به متحد جنبش محیط زیست
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن اشاره شده است که برای یافتن راهحلی بلندمدت برای مسائل زیستمحیطی، باید «ریشه مشکلات را بیابیم و باید آنها را غیرفعال کنیم». این نشان میدهد که یافتن ریشه مسئله و برخورد با آن، یک راهحل اساسی و بلندمدت است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>«باید ریشه مشکلات را بیابیم و باید آنها را غیرفعال کنیم»</span></p>
#         <p><strong>Keywords:</strong> ["'محیط زیست'", "'درمان حمایتی'", "'پیشرفتهای علمی'", "'فناوری'", "'جمعیت'", "'سبک زندگی'", "'مشکلات'", "'ریشه'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 6:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>ورزش‌های زمستانی روی تپه، از جمله اسکی و اسنوبورد، ورزش‌های پرطرفداری هستند که در آنها با استفاده از چوب اسکی یا اسنوبورد متصل به پاهایتان روی زمین‌های شیب‌دار پوشیده از برف سرمی‌خورید. اسکی فعالیت اصلی سفر است که علاقه‌مندان زیادی دارد و گهگاه با نام «اسکی گردی» شناخته می شود، یعنی برنامه ریزی کل تعطیلات حول محور اسکی کردن در یک محل خاص. ایده اسکی‌بازی خیلی قدیمی است - قدمت نقاشی‌های غارها که اسکی بازها را نشان می‌دهد به 5000 سال قبل از میلاد باز می‌گردد. ورزش اسکی روی تپه حداقل به قرن 17 ام برمی‌گردد، و در سال 1861، اولین باشگاه تفریحی اسکی را نروژی‌ها در استرالیا افتتاح کردند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>مطابق با متن، حدود چه زمانی اسکی‌بازی اولین بار به عنوان ورزش شناخته شد؟</span></p>
#         <p><strong>Original Answer:</strong> 4</p>
#         <p><strong>Predicted Answer:</strong> 4</p>
#         <p><strong>Options:</strong>
#             <br>1: قرن هجدهم
#             <br>2: 5000 سال قبل از میلاد
#             <br>3: 1861
#             <br>4: قرن هفدهم
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>متن اشاره میکند که ورزش اسکی روی تپه «حداقل» به قرن هفدهم برمیگردد. این بدان معنی است که ممکن است تاریخ دقیق آن ناشناخته باشد، اما میدانیم که این ورزش حداقل از قرن هفدهم وجود داشته و به عنوان ورزشی تفریحی شناخته میشده است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>ورزش اسکی روی تپه حداقل به قرن 17 ام برمیگردد</span></p>
#         <p><strong>Keywords:</strong> ['"ورزشهای زمستانی"', '"اسکی"', '"اسنوبورد"', '"تپه"', '"ورزش"', '"تفریحی"', '"سفر"', '"اسکی گردی"', '"ایده"', '"اسکیبازی"', '"قدیمی"', '"نقاشیهای غار"', '"تاریخ"', '"قرن 17"', '"باشگاه"', '"نروژی"', '"استرالیا"', '"قرن هجدهم"', '"5000 سال قبل از میلاد"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 7:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>ACMA همچنین نتیجه گرفت که علیرغم اینکه این ویدئو در اینترنت پخش شده است ولی Big Brother از قوانین سانسور محتوای آنلاین تخطی نکرده است، زیرا این رسانه‌ها در وب‌سایت Big Brother ذخیره نشده بودند. قانون خدمات پخش مقررات محتوای اینترنتی را مشخص می‌کند، اما وقتی محتوایی جزء محتوای اینترنتی محسوب می‌شود که به‌شکل فیزیکی روی یک سرور مستقر باشد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>برای اینکه رسانه تحت مقوله محتوای اینترنتی لحاظ شود، باید چه پارامترهایی داشته باشد؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: باید از طریق اینترنت پخش شود
#             <br>2: باید به صورت فیزیکی در سروری قرار گیرد
#             <br>3: نمی‌تواند روی وبسایت ذخیره شود
#             <br>4: باید توسط ACMA تأیید شود
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته میشود که محتوا برای اینکه جزء "محتوای اینترنتی" محسوب شود، باید "بهشکل فیزیکی روی یک سرور مستقر باشد". این به این معنی است که پارامتر اصلی برای قرار گرفتن در این دسته، ذخیره شدن فیزیکی محتوا بر روی یک سرور است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>قانون خدمات پخش مقررات محتوای اینترنتی را مشخص میکند، اما وقتی محتوایی جزء محتوای اینترنتی محسوب میشود که بهشکل فیزیکی روی یک سرور مستقر باشد.</span></p>
#         <p><strong>Keywords:</strong> ["'قانون خدمات پخش'", "'محتوای اینترنتی'", "'سرور'", "'ذخیرهسازی فیزیکی'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 8:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>عرفان عبارت است از جستجوی ارتباط، شناخت یا درک آگاهانه از یک واقعیت، الوهیت، حقیقت معنوی یا خدا. این مؤمن خواستار تجربه، بصیرت یا بینشی مستقیم نسبت به واقعیت الهی/خدا یا خدایان است. پیروان روش‌های خاصی از معاش، یا اعمالی که به قصد شکل دادن این تجارب انجام می‌گیرند، را دنبال می‌کنند. ویژگی که عرفان را از سایر اشکال باورهای مذهبی و عبادی متمایز می‌کند تأکید آن بر تجربه مستقیم شخصی از یک حالت هشیاری منحصربه‌فرد است، بخصوص تجربه‌ای که از خصلت آرامش، بینش، سعادت یا حتی نشاط برخوردار باشد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به متن، کدام یک از موارد زیر مورد توجه عرفان نیست؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: جستجوی شهود به واقعیت الهی
#             <br>2: طلب بینش از طریق تجربیات مشترک و همگانی
#             <br>3: تأکید بر حالت سعادتمند خودآگاه
#             <br>4: طلب درک آگاهانه الوهیت
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>عرفان به دنبال تجربه مستقیم و شخصی از واقعیت الهی است که می تواند شامل شهود، بینش یا درک آگاهانه از الوهیت باشد. اگرچه عرفان بر تجربیات معنوی تأکید دارد، اما این تجربیات منحصر به فرد و خاص هر فرد هستند، نه تجربیات مشترک و همگانی. بنابراین، "طلب بینش از طریق تجربیات مشترک و همگانی" موردی است که عرفان به دنبال آن نیست.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>عرفان عبارت است از جستجوی ارتباط، شناخت یا درک آگاهانه از یک واقعیت، الوهیت، حقیقت معنوی یا خدا. این مؤمن خواستار تجربه، بصیرت یا بینشی مستقیم نسبت به واقعیت الهی/خدا یا خدایان است.</span></p>
#         <p><strong>Keywords:</strong> ["'عرفان'", "'تجربه مستقیم'", "'واقعیت الهی'", "'بینش'", "'درک آگاهانه'", "'معنویت'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 9:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>محمد عمیقا به امور فراتر از این زندگی دنیوی علاقه مند بود. او عادت داشت که برای تامل به غاری به نام «حرا» در کوه «نور» برود. خود غار که طی اعصار سالم مانده است بیانگر تصور خیلی روشن از گرایش‌های روحانی حضرت محمد دارد. این غار در بالای یکی از کوه‌های شمال مکه واقع شده و به‌طور کامل از باقی نقاط جهان جدا شده است. در حقیقت، حتی اگر کسی بداند که چنین چیزی وجود دارد، پیدا کردنش کار ساده‌ای نیست. وقتی‌که وارد غار شدید، در یک انزوا کامل خواهید بود. هیچ چیزی غیر از آسمان صاف و زیبا در بالای سر و کوه‌های فراوان در اطراف دیده نمی‌شود. از داخل این غار بخش زیادی از این دنیا را نمی‌توان دید یا شنید.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>بر اساس متن، غار محمد بیانگر چه چیزی درباره اعمال یا ارزش‌های روحانی او بود؟</span></p>
#         <p><strong>Original Answer:</strong> 1</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: او برای آرامش و انزوا ارزش قائل بود
#             <br>2: صدای بیرون به تأمل او کمک می‌کرد
#             <br>3: به زمان خیلی کمی برای تنهایی نیاز داشت
#             <br>4: نگران این بود که دیده یا شنیده شود
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>غار حرا، مکانی بود که محمد برای تأمل و تفکر انتخاب کرده بود. این غار در بالای کوهی در شمال مکه قرار داشت و به دلیل موقعیت دورافتاده و جدا افتادهاش، فضایی آرام و منزوی را فراهم میکرد. توصیفاتی مانند "انزوا کامل"، "جدا شدن از باقی نقاط جهان" و "نبود هیچ چیز جز آسمان و کوهها در اطراف" نشان میدهد که محمد ارزش زیادی برای آرامش و تنهایی قائل بود تا بتواند به تأملات روحانی خود بپردازد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>خود غار که طی اعصار سالم مانده است بیانگر تصور خیلی روشن از گرایشهای روحانی حضرت محمد دارد. این غار در بالای یکی از کوههای شمال مکه واقع شده و بهطور کامل از باقی نقاط جهان جدا شده است. وقتیکه وارد غار شدید، در یک انزوا کامل خواهید بود. هیچ چیزی غیر از آسمان صاف و زیبا در بالای سر و کوههای فراوان در اطراف دیده نمیشود.</span></p>
#         <p><strong>Keywords:</strong> ['"غار حرا"، "تأمل"، "کوه نور"، "انزوا"، "آرامش"، "جدا شدن از دنیا"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 10:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>کودکان از زمان کودکی نسبت به نژاد و کلیشه های نژادی آگاهی کسب می‌کنند و این کلیشه های نژادی بر رفتار تأثیر می گذارند. برای نمونه، کودکانی که با یک اقلیت‌نژادی شناخته می‌شوند که به‌صورت کلیشه‌ای عملکرد خوبی در مدرسه ندارد، به‌محض اینکه از این کلیشه نژاد خود آگاه می‌شوند تلاش می‌کنند تا عملکرد خوبی در مدرسه نداشته باشند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به نظریه ارائه شده در متن، برای کودکانی که با یک اقلیت‌نژادی شناخته می‌شوند که به‌صورت کلیشه‌ای رفتار تهدیدآمیز دارد، چه اتفاقی ممکن است رخ دهد؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: کودک سعی می‌کند از درگیر شدن در رفتارهای تهدیدآمیز خودداری کند
#             <br>2: احتمال بیشتری وجود دارد که کودک درگیر رفتارهای تهدیدآمیز شود
#             <br>3: کودک در موقعیت‌های اجتماعی کناره‌گیری می‌کند
#             <br>4: کودک از تعامل با سایر اقلیت‌های نژادی امتناع خواهد کرد
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به نظریه ارائه شده در متن، کودکان بر اساس آگاهی از کلیشههای نژادی خود، تلاش میکنند تا رفتاری داشته باشند که با این کلیشهها همسو باشد. در این مورد خاص، کودکانی که با اقلیت نژادی مرتبط هستند که بهصورت کلیشهای رفتار تهدیدآمیز دارد، ممکن است تلاش کنند تا از درگیر شدن در چنین رفتارهایی خودداری کنند. این امر به دلیل تمایل کودک برای هماهنگ شدن با انتظارات اجتماعی و اجتناب از تقویت کلیشههای منفی است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>کودکان از زمان کودکی نسبت به نژاد و کلیشه های نژادی آگاهی کسب میکنند و این کلیشه های نژادی بر رفتار تأثیر می گذارند. ... کودکانی که با یک اقلیتنژادی شناخته میشوند ... بهمحض اینکه از این کلیشه نژاد خود آگاه میشوند تلاش میکنند تا با آن همسو شوند.</span></p>
#         <p><strong>Keywords:</strong> ['"کودک"', '"نژاد"', '"کلیشه"', '"رفتار"', '"اقلیت"', '"مدرسه"', '"خودآگاهی"', '"همسو"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 11:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>به دستور هروستراتوس، معبد آرتمیس در افسوس در 21 ژوئیه 356 قبل از میلاد آتش زده و تخریب شد. طبق این داستان، انگیزه او کسب شهرت به هر قیمتی بود. افسسیان با عصبانیت اعلام کردند نام هروستراتوس هرگز ثبت نشود. مورخ یونانی استرابو بعداً به نام آن اشاره كرده و اینگونه است كه امروزه آن را می‌شناسیم. در همان شبی که اسکندر مقدونی به دنیا آمد، معبد نابود شد. الکساندر، در جایگاه پادشاه، پیشنهاد کرد که هزینه بازسازی مقبره را بپردازد، اما پیشنهادش رد شد. بعدها پس از مرگ الکساندر، مقبره در سال 323 قبل از میلاد بازسازی شد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>چه کسی باعث آگاهی ما از آتش افروزی است که معبد را ویران کرد؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: افسسیان
#             <br>2: الکساندر
#             <br>3: استرابو
#             <br>4: آرتمیس
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که مورخ یونانی استرابو بود که به نام هروستراتوس اشاره کرد و باعث شد ما امروزه از این آتش افروزی و نقش او در ویرانی معبد آگاه باشیم.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>مورخ یونانی استرابو بعداً به نام آن اشاره كرده و اینگونه است كه امروزه آن را میشناسیم.</span></p>
#         <p><strong>Keywords:</strong> ['"هروستراتوس"، "معبد آرتمیس"، "افسوس"، "آتشسوزی"، "مورخ یونانی"، "استرابو"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 12:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>پیش از این خبرگزاری چینی شینهووا از ربوده شدن هواپیما خبر داده بود. گزارشات بعدی بیان کرد که هواپیما تهدید بمب‌گذاری داشته است و با تغییر مسیر به سمت افغانستان، در قندهار نشسته است. گزارشات اولیه بیان می‌دارد که هواپیما پس از اینکه اجازه فرود اضطراری در اورومچی به آن داده نشده به افغانستان بازگشته بود.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>چه چیز در آخرین گزارش از آژانس خبری شینهووا بیان نشد؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: هواپیما یک تهدید بمب‌گذاری دریافت کرد
#             <br>2: هواپیما در اورومچی فرود آمد
#             <br>3: مسیر هواپیما به سمت افغانستان عوض شد
#             <br>4: هواپیما در قندهار فرود آمد
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>گزارش اولیه شینهووا تنها به ربوده شدن هواپیما اشاره کرده بود و هیچ اطلاعاتی درباره تهدید بمبگذاری، تغییر مسیر به سمت افغانستان یا فرود در قندهار ارائه نکرد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>پیش از این خبرگزاری چینی شینهووا از ربوده شدن هواپیما خبر داده بود.</span></p>
#         <p><strong>Keywords:</strong> ["'ربوده شدن هواپیما'", "'تهدید بمبگذاری'", "'تغییر مسیر'", "'افغانستان'", "'قندهار'", "'فرود اضطراری'", "'اورومچی'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 13:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>تماشای شکوفه‌های گیلاس (هانامی) از قرن هشتم بخشی از فرهنگ ژاپن بوده است. این مفهوم از چین آمده است که گل منتخبش شکوفه‌های آلو بوده است. در ژاپن، نخستین مراسم شکوفه گیلاس توسط امپراتور و تنها برای خود او و اعضای اشرافی نزدیک به دربار امپراتوری برگزار می‌شود.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>چه کسانی میزبان اولین گروه‌های مختص مشاهده شکوفه‌های گیلاس بودند؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3-امپراطور ژاپن</p>
#         <p><strong>Options:</strong>
#             <br>1: امپراطور چین
#             <br>2: اشراف ژاپنی
#             <br>3: امپراطور ژاپن
#             <br>4: اشراف چینی
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته میشود که "در ژاپن، نخستین مراسم شکوفه گیلاس توسط امپراتور [ژاپن] و تنها برای خود او و اعضای اشرافی نزدیک به دربار امپراتوری برگزار میشود." این نشان میدهد که امپراتور ژاپن میزبان اولین گروههای مشاهده شکوفههای گیلاس بوده است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>در ژاپن، نخستین مراسم شکوفه گیلاس توسط امپراتور و تنها برای خود او و اعضای اشرافی نزدیک به دربار امپراتوری برگزار میشود.</span></p>
#         <p><strong>Keywords:</strong> ['"ژاپن"، "امپراطور"، "مراسم شکوفه گیلاس"، "میزبان"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 14:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>برای درک تمپلارها باید زمینه ای که موجب ایجاد این نظم شده است را درک کنید. عصری که این رویدادها در آن اتفاق افتاد را عموما قرون وسطی می‌نامند، دوره‌ای از تاریخ اروپا در قرن یازدهم، دوازدهم، و سیزدهم (1000 تا 1300 پس از میلاد). قرون وسطی بالا بعد از قرون وسطی شکل گرفت و بعد از آن قرون وسطی آخری بود، که توسط کنوانسیون در حدود 1500 به پایان می رسد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>کدام دوره زمانی قبل از عصر تمپلارها بوده است؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: قرون وسطی اخری
#             <br>2: قرن 12ام
#             <br>3: قرون وسطی بالا
#             <br>4: قرن 13ام
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که "قرون وسطی بالا بعد از قرون وسطی شکل گرفت". بنابراین، قرون وسطی بالا بعد از دورهای که تمپلارها در آن وجود داشتند، اتفاق افتاد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>قرون وسطی بالا بعد از قرون وسطی شکل گرفت</span></p>
#         <p><strong>Keywords:</strong> ['"تمپلارها"، "قرون وسطی"، "قرون وسطی بالا"، "قرون وسطی آخری"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 15:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>قبل از رسیدن اسپانیایی‌ها در قرن 16ام، شیلی شمالی تحت حاکمیت اینکا بود درحالیکه قوم ماپوچه در شیلی مرکزی و جنوبی زندگی می‌کردند. ماپوچه همچنین یکی از آخرین گروه‌های بومی آمریکا بودند که بطور کامل در حکومت اسپانیایی‌زبان تا پس از استقلال شیلی جذب نشدند. اگرچه کشور شیلی در 1810 اعلام استقلال کرد(در بحبوحه جنگ‌های ناپلئونی که باعث شد اسپانیا چند سال بدون دولتی با عملکرد مرکزی باقی بماند)، پیروزی قطعی بر اسپانیا تا سال 1818 بدست نیامد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>مطابق متن، کدام‌یک از موارد زیر در سال 1810 رخ نداد؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: دولت مرکزی وجود نداشت
#             <br>2: شیلی بر اسپانیا پیروز شد
#             <br>3: جنگ‌های ناپلئونی درحال انجام بود
#             <br>4: شیلی اعلام استقلال کرد
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>متن اشاره میکند که شیلی در سال 1810 اعلام استقلال کرد، اما پیروزی قطعی بر اسپانیا تا سال 1818 بدست نیامد. بنابراین، گزینه 2 که بیان میکند "شیلی بر اسپانیا پیروز شد" در سال 1810 رخ نداده است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>اگرچه کشور شیلی در 1810 اعلام استقلال کرد، پیروزی قطعی بر اسپانیا تا سال 1818 بدست نیامد.</span></p>
#         <p><strong>Keywords:</strong> ["'شیلی'", "'اعلام استقلال'", "'پیروزی بر اسپانیا'", "'1810'", "'1818'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 16:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>تیم ملی آفریقای جنوبی تیم ملی راگبی نیوزلند (All Blacks) را در یک مسابقه Tri Nations (سه ملیتی) اتحاد راگبی در ورزشگاه رویال بافوکنگ در راستنبرگ آفریقای جنوبی شکست داد. امتیاز نهایی یک پیروزی یک امتیازی، 21 بر 20 بود و به 15 برد متوالی All Blacks پایان داد. این مسابقه برای تیم اسپرینگ باکس منجر به پنجمین باخت پیاپی آن شد. این یک مسابقه نهایی برای All Blacks بود، که دو هفته پیش قهرمان این جام شده بود. هفته بعد مسابقه نهایی این سری در ورزشگاه الیس پارک در ژوهانسبورگ برگزار می‌شود و تیم ملی راگبی آفریقای جنوبی Springboks با استرالیا بازی می‌کند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>اسپرینگ باکس مسابقه بعدی خود را در کجا بازی خواهد کرد؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: استرالیا
#             <br>2: راستنبرگ
#             <br>3: ژوهانسبورگ
#             <br>4: نیوزلند
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته میشود که مسابقه بعدی سری در ژوهانسبورگ برگزار میشود و تیم اسپرینگ باکس در آن بازی خواهد کرد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>هفته بعد مسابقه نهایی این سری در ورزشگاه الیس پارک در ژوهانسبورگ برگزار میشود و تیم ملی راگبی آفریقای جنوبی Springboks با استرالیا بازی میکند.</span></p>
#         <p><strong>Keywords:</strong> ["'راگبی'", "'ورزشگاه'", "'آفریقای جنوبی'", "'استرالیا'", "'ژوهانسبورگ'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 17:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>به این پدیده pH شیمیایی گفته می‌شود. می‌توانید یک شاخص با استفاده از آب کلم قرمز درست کنید. آب کلم بسته میزان اسیدی یا بازی (قلیایی) بودن ماده شیمیایی تغییر رنگ می‌دهد. سطح pH توسط مقدار یون‌های هیدروژن (H در pH) در ماده شیمیایی تست‌شده نشان داده می‌شود. یون‌های هیدروژن پروتون‌هایی هستند که الکترون از آنها گرفته شده است (زیرا اتم‌های هیدروژن فقط از یک پروتون و یک الکترون تشکیل می‌شوند).</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>چه چیزی از یون‌های هیدروژن حذف شد؟</span></p>
#         <p><strong>Original Answer:</strong> 4</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: پروتون
#             <br>2: pH
#             <br>3: قلیا
#             <br>4: الکترون‌ها
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته میشود که «یونهای هیدروژن پروتونهایی هستند که الکترون از آنها گرفته شده است». این نشان میدهد که چیزی که از یونهای هیدروژن حذف شده، الکترون است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>یونهای هیدروژن پروتونهایی هستند که الکترون از آنها گرفته شده است.</span></p>
#         <p><strong>Keywords:</strong> ["'pH'", "'شیمیایی'", "'شاخص'", "'آب کلم قرمز'", "'اسیدی'", "'بازی'", "'قلیایی'", "'یونهای هیدروژن'", "'پروتون'", "'الکترون'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 18:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>«هسپرونیکوس الیزابتا» گونه‌ای از تیره «دونده‌خزندگان» است و پسرعموی ولاسیراپتور است. اعتقاد می‌رفت این پرنده شکاری تمام‌پر و خون‌گرم صاف روی دوپایش راه می‌رفته و پنجه‌هایی شبیه ولاسیراپتور داشته است. پنجه دومش بزرگتر بود که سبب نام‌گذاری «Hesperonychus» به معنی «پنجه غربی» شد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>معنای «Hesperonychus» (هسپرونیکوس) از کدام ویژگی فیزیکی این گونه گرفته شده است؟</span></p>
#         <p><strong>Original Answer:</strong> 1</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: پنجه(ها)
#             <br>2: بدن پوشیده از پر
#             <br>3: پاها
#             <br>4: منقار
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>نام "هسپرونیکوس" به معنی "پنجه غربی" است که اشاره به ویژگی فیزیکی متمایز این گونه، یعنی داشتن یک پنجه بزرگ در پا دارد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>نام «هسپرونیکوس» به معنی «پنجه غربی» است که به دلیل داشتن یک پنجه بزرگ در پاهایشان نامگذاری شدهاند.</span></p>
#         <p><strong>Keywords:</strong> ["'هسپرونیکوس'", "'پنجه'", "'غربی'", "'پنجه_بزرگ'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 19:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>یک پلیس سابق فیلیپینی با ربودن یک اتوبوس در مانیل، پایتخت فیلیپین، گردشگران هنگ کنگی را به گروگان گرفته است. رونالدو مندوزا با اسلحه M16 خود به گردشگران شلیک کرد. چندین تن از گروگان‌ها نجات یافته‌اند و تاکنون مرگ حداقل شش نفر تایید شده است. شش گروگان شامل كودكان و سالمندان، همینطور عكاسان فیلیپینی، در ابتدا آزاد شدند. عکاس‌ها سپس جای یک زن سالخورده که نیاز به دستشویی داشت را گرفتند. مندوزا با گلوله از پای درآورده شد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به متن، رولاندو مندوزا چه کسی را گروگان نگرفت؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 4</p>
#         <p><strong>Options:</strong>
#             <br>1: گردشگران
#             <br>2: پلیس
#             <br>3: کودکان
#             <br>4: عکاسان
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>متن اشاره میکند که رونالدو مندوزا، گردشگران هنگ کنگی را گروگان گرفته است. همچنین، در ادامه ذکر شده که چندین تن از گروگانها نجات یافتهاند و عکاسان فیلیپینی در ابتدا آزاد شدند. بنابراین، میتوان نتیجه گرفت که مندوزا عکاسان را گروگان نگرفته است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>رونالدو مندوزا، گردشگران هنگ کنگی را گروگان گرفت. عکاسان فیلیپینی در ابتدا آزاد شدند.</span></p>
#         <p><strong>Keywords:</strong> ['"گروگان"، "رونالدو مندوزا"، "گردشگران هنگ کنگی"، "عکاسان فیلیپینی"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 20:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>هدف اصلی علم کشف نحوه کار جهان از طریق روش علمی است. این روش در واقع اکثر تحقیقات علمی را هدایت می‌کند. با این‌حال این مورد به تنهایی نیست، آزمایش و یک تجربه است که برای از بین بردن یک یا چند فرضیه احتمالی، پرسیدن سؤال‌ها و ایجاد مشاهدات و نیز هدایت تحقیقات علمی لازم است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به این متن، چه چیزی به هدایت تحقیقات علمی کمک نمی‌کند؟</span></p>
#         <p><strong>Original Answer:</strong> 1</p>
#         <p><strong>Predicted Answer:</strong> 1-روش علمی به تنهایی</p>
#         <p><strong>Options:</strong>
#             <br>1: روش علمی به تنهایی
#             <br>2: انجام مشاهدات
#             <br>3: حذف فرضیه‌های ممکن
#             <br>4: انجام آزمایشات
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که روش علمی اکثر تحقیقات علمی را هدایت میکند، اما اشاره شده که این روش به تنهایی نیست که این کار را انجام میدهد. بنابراین، روش علمی به تنهایی کافی نیست و باید همراه با سایر مراحل مانند آزمایش، تجربه، پرسیدن سوالات، حذف فرضیهها و انجام مشاهدات باشد تا بتواند به هدایت تحقیقات علمی کمک کند.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>هدف اصلی علم کشف نحوه کار جهان از طریق روش علمی است. این روش در واقع اکثر تحقیقات علمی را هدایت میکند. با اینحال این مورد به تنهایی نیست</span></p>
#         <p><strong>Keywords:</strong> ['"روش علمی"، "تحقیقات علمی"، "آزمایش"، "مشاهدات"، "فرضیه"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 21:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>وقتی با کسی تماس می‌گیرید که هزاران مایل با شما فاصله دارد، دارید از ماهواره استفاده می‌کنید. ماهواره در فضا تماس را دریافت می‌کند و آن را تقریباً به‌صورت آنی به پایین منعکس می‌کند. این ماهواره توسط یک موشک به فضا فرستاده شد. دانشمندان از تلسکوپ‌ها در فضا استفاده می‌کنند زیرا جو زمین برخی از نورها و تصاویر را تحریف می‌کند. برای قرار دادن یک ماهواره یا تلسکوپ در فضا نیاز به موشکی بزرگ با ارتفاع بیش از 100 پا می‌باشد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>کدام مورد نشانگر انعکاس تماس‌ از راه دور به پایین در زمین است؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: تلسکوپ‌ها
#             <br>2: ماهواره‌ها
#             <br>3: چراغ‌ها
#             <br>4: موشک‌ها
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که ماهوارهها تماسهای تلفنی را دریافت میکنند و آنها را تقریباً بهصورت آنی به زمین منعکس میکنند. بنابراین، ماهوارهها نشاندهنده انعکاس تماسهای تلفنی از راه دور به پایین در زمین هستند.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>وقتی با کسی تماس میگیرید که هزاران مایل با شما فاصله دارد، دارید از ماهواره استفاده میکنید. ماهواره در فضا تماس را دریافت میکند و آن را تقریباً بهصورت آنی به پایین منعکس میکند.</span></p>
#         <p><strong>Keywords:</strong> ["'تماس تلفنی'", "'فاصله'", "'ماهواره'", "'فضا'", "'انعکاس'", "'موشک'", "'تلسکوپ'", "'جو زمین'", "'نور'", "'تصویر'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 22:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>اکثر معابد یک جشنواره سالانه دارند که از آخر ماه نوامبر تا وسط ماه مه ادامه دارد و طبق تقویم سالانه هر معبد متفاوت است. اکثر جشنواره‌های معبد به‌عنوان بخشی از جشن سالگرد معبد یا زادروز خدای حاکم یا هر رویداد مهم مرتبط با معبد برگزار می‌شود. جشنواره‌های معبد کرالا با داشتن موکب‌های منظم از فیل‌های مزین، ارکستر معبد و دیگر مراسم، رویدادی بسیار دیدنی هستند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>کدام رویداد مرتبط با جشن گرفتن جشنواره‌های معبد نیست؟</span></p>
#         <p><strong>Original Answer:</strong> 1</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: تولد فیل
#             <br>2: سالگرد معبد
#             <br>3: زادروز خدای حاکم
#             <br>4: رویدادهای مهم مربوط به معبد
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>جشنوارههای معبد معمولاً با رویدادهایی مانند جشن سالگرد معبد، تولد خدایان یا سایر رویدادهای مهم مرتبط هستند. هیچ اشارهای به تولد فیلها به عنوان بخشی از این جشنها نشده است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>جشنوارههای معبد کرالا با داشتن موکبهای منظم از فیلهای مزین، ارکستر معبد و دیگر مراسم، رویدادی بسیار دیدنی هستند.</span></p>
#         <p><strong>Keywords:</strong> ['"جشنواره سالانه"، "معبد"، "جشن سالگرد"، "زادروز خدایان"، "فیلهای مزین"، "ارکستر معبد"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 23:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>آنفولانزای مرغی، یا به‌اصطلاح رسمی‌تر آن آنفولانزای پرندگان، می‌تواند سبب ابتلای پرندگان و نیز پستانداران شود. تاکنون کمتر از هزار مورد در انسان گزارش شده است، اما برخی از آنها کشنده بوده است. بیشتر آنها افرادی را درگیر کرده‌اند که با مرغداری کار می‌کنند، اما خطراتی برای پرنده‌نگری نیز وجود دارد.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>مطابق با متن، کدام‌یک از عبارت‌های زیر آنفولانزای پرندگان را به‌طور دقیق توصیف می‌کند؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: فقط کارکنان مرغداری به آنفولانزا مبتلا شده‌اند
#             <br>2: موارد بیشتری در انسان‌ها نسبت به پرنده‌ها گزارش شده است
#             <br>3: تماشاکنندگان پرندگان در خطر مبتلا شدن هستند
#             <br>4: تمام موارد گزارش شده در انسان‌ها مرگبار بوده است
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که آنفولانزای پرندگان میتواند هم پرندگان و هم پستانداران را مبتلا کند. همچنین، اشاره شده که این بیماری کمتر از هزار بار در انسانها گزارش شده، اما برخی از این موارد کشنده بوده است. آن دسته از افرادی که بیشتر در معرض خطر بودهاند، کسانی هستند که در مرغداری کار میکنند، اما همچنین به این نکته اشاره شده که پرندهنگری نیز ممکن است خطراتی داشته باشد. بنابراین، گزینه سوم به درستی نشان میدهد که تماشاکنندگان پرندگان (پرندهنگرها) در معرض خطر ابتلا به این بیماری قرار دارند.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>آنفولانزای پرندگان میتواند هم پرندگان و هم پستانداران را مبتلا کند. ... بیشتر آنها افرادی را درگیر کرده که با مرغداری کار میکنند، اما خطراتی برای پرندهنگری نیز وجود دارد.</span></p>
#         <p><strong>Keywords:</strong> ['"آنفولانزای پرندگان"، "پرندگان"، "پستانداران"، "انسان"، "مرگبار"، "کارکنان مرغداری"، "پرندهنگری"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 24:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>در طی سه دهه آخر، علیرغم اینکه چین رسماً دولت کمونیستی مانده است، نوعی اقتصاد بازار را توسعه داده است. اولین اصلاحات اقتصادی تحت رهبری «دنگ شیائوپینگ» صورت گرفت. از آن زمان به بعد، اقتصاد چین 90 برابر شده است. سال گذشته چین برای اولین بار خودروهای بیشتری از آلمان صادر کرد و ایالات متحده که بزرگترین بازار این صنعت را دارد را مغلوب کرد. تولید ناخالص داخلی چین توانست طی دو دهه از ایالات متحده بالاتر شود.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به متن، کدام یک از عبارات زیر به درستی نشانگر اقتصاد چین نیست؟</span></p>
#         <p><strong>Original Answer:</strong> 4</p>
#         <p><strong>Predicted Answer:</strong> 4</p>
#         <p><strong>Options:</strong>
#             <br>1: اقتصاد چین از زمان انجام اصلاحات به طور تصاعدی رشد کرده است
#             <br>2: چین بازار بزرگتری برای صادرات خودرو نسبت به ایالات متحده دارد
#             <br>3: چین در نهایت توانست GDP بزرگتری نسبت به ایالات متحده داشته باشد
#             <br>4: چین هرگز بیشتر از آلمان خودرو صادر نکرده است
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>متن میگوید که چین برای اولین بار خودروهای بیشتری نسبت به آلمان صادر کرد، بنابراین گزینه چهارم که ادعا میکند چین هرگز بیشتر از آلمان خودرو صادر نکرده است، نادرست است و به درستی اقتصاد چین را نشان نمیدهد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>سال گذشته چین برای اولین بار خودروهای بیشتری از آلمان صادر کرد</span></p>
#         <p><strong>Keywords:</strong> ['"چین"، "اقتصاد"، "صادرات خودرو"، "آلمان"، "بازار"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 25:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>سپاه مهندسی ارتش ایالات متحده تخمین زده که 6 اینچ باران می‌تواند از آب‌بندهای از قبل‌آسیب‌دیده نفوذ کند. بخش «ناینت وارد» (Ninth Ward) که در زمان توفان کاترینا شاهد سیل به بلندی 20 فوت بود اکنون با سر ریز شدن آببند اطراف تا کمر در آب فرو رفته است. در قسمتی به عرض 100 فوت، آب در حال ریختن به داخل خاکریز است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>در طول طوفان کاترینا، در Ninth Ward چه اتفاقی رخ داد؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: آب سیل 100 فوت عرض داشت
#             <br>2: آب با ارتفاع تا کمر از روی آب‌بند گذشت
#             <br>3: آب‌های سیل 20 فوت ارتفاع داشت
#             <br>4: 6 اینچ بارندگی از آب‌بند آسیب‌دیده نفوذ کرد
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که در زمان توفان کاترینا، بخش «ناینت وارد» شاهد سیل به بلندی 20 فوت بوده است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>در زمان توفان کاترینا، بخش «ناینت وارد» شاهد سیل به بلندی 20 فوت بود.</span></p>
#         <p><strong>Keywords:</strong> ["'سپاه مهندسی ارتش'", "'ایالات متحده'", "'باران'", "'آببند'", "'ناینت وارد'", "'توفان کاترینا'", "'سیل'", "'آب'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 26:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>پس از وقوع تصادف، «گیبسون» به بیمارستان منتقل شد ولی کمی پس از آن درگذشت. راننده کامیونی که 64 سال سن دارد در تصادف زخمی نشد. خود خودرو تقریباً‌ ساعت 1200 گرینویچ همان روز از صحنه تصادف برده شد. شخصی که در یک گاراژ نزدیک محل وقوع تصادف کار می‌کرد گفت: «کودکان منتظر بودند که از جاده عبور کنند و همگی جیغ می‌زدند و گریه می‌کردند.» آنها همگی از محلی که حادثه رخ داده بود با دویدن به عقب رفتند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>چه کسی در تصادف صدمه دید؟</span></p>
#         <p><strong>Original Answer:</strong> 1</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: «گیبسون»
#             <br>2: کارگر گاراژ
#             <br>3: کودکان
#             <br>4: راننده کامیون
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که «گیبسون» پس از تصادف به بیمارستان منتقل شد اما کمی بعد درگذشت. بنابراین، میتوان نتیجه گرفت که او در تصادف آسیب دیده بود.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>«گیبسون» پس از وقوع تصادف به بیمارستان منتقل شد ولی کمی پس از آن درگذشت.</span></p>
#         <p><strong>Keywords:</strong> ["'تصادف'", "'گیبسون'", "'بیمارستان'", "'درگذشت'", "'راننده کامیون'", "'خودرو'", "'کودکان'", "'گاراژ'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 27:</strong></p>
# ...
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته میشود که ستارگان با ادغام اتمهای هیدروژن، انرژی تولید میکنند. دانشمندان نیز در تلاشند راکتوری بسازند که به همین روش، یعنی ادغام اتمی، انرژی تولید کند. بنابراین، یک راکتور همجوشی کارآمد انرژی تولید خواهد کرد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>ستارگان با ادغام اتمهای هیدروژن، انرژی تولید میکنند. دانشمندان در تلاش برای ساخت راکتوری هستند که به همین روش انرژی تولید کند.</span></p>
#         <p><strong>Keywords:</strong> ["'راکتور همجوشی'", "'انرژی'", "'اتم'", "'هیدروژن'", "'ستاره'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 43:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>یکی از شایع‌ترین مشکلات هنگام تبدیل کردن فیلم به قالب DVD بیرون زدن تصویر از کادر است. اکثر تلویزیون‌ها طوری ساخته شده‌است که مورد پسند مردم باشد. به آن دلیل، هر آنچه در تلویزیون مشاهده می‌کنید، کناره‌هایش از بالا، پایین و دو طرف برش خورده است. این برای اطمینان از آن ساخته شده تا تصویر به درستی در کل صفحه نمایش داده می‌شود. به آن overscan گفته می‌شود. متأسفانه وقتی یک DVD می‌سازید، کناره‌هایش نیز به احتمال زیاد از کادر خارج می‌شود و اگر زیرنویس این ویدئو به پایین تصویر خیلی نزدیک باشد، کامل نشان داده نمی‌شوند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>چرا کناره تصاویر در تلویزیون برش خورده می‌شود؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: برای ایجاد امکان زیرنویس نوشتن
#             <br>2: برای اینکه تصویر با کل صفحه تطبیق پیدا کند
#             <br>3: برای ایجاد امکان تبدیل ساده به فرمت‌های دیگر
#             <br>4: برای بیش از اندازه نزدیک به پایین برش خوردن زیرنویس‌ها
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که تلویزیونها طوری ساخته شدهاند که مورد پسند مردم باشند و به همین دلیل کنارههای تصویر برش خورده است تا تصویر به درستی در کل صفحه نمایش داده شود.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>اکثر تلویزیونها طوری ساخته شدهاست که مورد پسند مردم باشد. به آن دلیل، هر آنچه در تلویزیون مشاهده میکنید، کنارههایش از بالا، پایین و دو طرف برش خورده است. این برای اطمینان از آن ساخته شده تا تصویر به درستی در کل صفحه نمایش داده میشود.</span></p>
#         <p><strong>Keywords:</strong> ['"تلویزیون"', '"برش"', '"تصویر"', '"صفحه"', '"مردم"', '"پسند"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 44:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>روش بارز پرواز با صندلی فرست کلاس یا بیزینس این است که مبلغ هنگفتی را در ازای امتیاز بسلفید (یا بهتر اینکه می‌توانید به شرکتتان بگویید که ترتیب این کار را بدهد). با این حال، ارزان بدست نمی‌آید: یک قانون کلی می‌گوید می‌توان انتظار داشت تا چهار برابر کرایه عادی که برای حالت اقتصادی پرداخت می‌شود برای حالت تجاری و یازده برابر آن را برای درجه یک بپردازید! بطور کل، جستجوی تخفیف برای صندلی‌های بیزینس و فرست کلاس در پروازها از نقطه A به B هیچ فایده‌ای ندارد. خطوط هوایی به خوبی می‌دانند که گروهی از مسافرین هوایی با شرایط اضطراری مایل به پرداخت پول زیاد برای دریافت مزیت سفر سریع و راحت می‌باشند و بر این اساس قیمت‌گذاری می‌کنند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>مطابق با متن، هنگام رزرو کلاس‌های بلیط مشخص، جستجو برای چه چیز وقت تلف کردن است؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: پروازهای مستقیم
#             <br>2: کلاس بیزینس
#             <br>3: تخفیف‌ها
#             <br>4: فرست کلاس
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته میشود که «جستجوی تخفیف برای صندلیهای بیزینس و فرست کلاس در پروازها از نقطه A به B هیچ فایدهای ندارد». این بدین معناست که جستجو برای تخفیف در این کلاسهای پروازی بیفایده است و وقت تلف کردن است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>«جستجوی تخفیف برای صندلیهای بیزینس و فرست کلاس در پروازها از نقطه A به B هیچ فایدهای ندارد.»</span></p>
#         <p><strong>Keywords:</strong> ["'پرواز'", "'بیزینس'", "'فرست کلاس'", "'تخفیف'", "'بیفایده'"]</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 45:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>آدام کوئردن، مدیر منابع مشترک، هنگام گفتگو با ویکی‌نیوز در ماه گذشته،‌ از این حذفیات ابراز سرخوردگی کرد. «او [ولز] از همان ابتدا به ما دروغ گفت. اول از همه، با وانمود کردن اینکه این به‌خاطر دلایل قانونی است. دوم، با وانمود کردن اینکه به حرف‌های ما گوش می‌کند، اما درست تا حذف هنرش پیش رفت.» خشم جامعه منجر به تلاش‌های جاری برای طرح سیاستی در خصوص محتوای جنسی برای این سایت شد که میزبان میلیون‌ها رسانه با دسترسی آزاد است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>کدام‌یک از موارد زیر دلیل سرخوردگی آدام کوئردن نیست؟</span></p>
#         <p><strong>Original Answer:</strong> 1</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: خط‌مشی جدید سایت درخصوص محتوای جنسی
#             <br>2: حذف هنر ولز
#             <br>3: عدم توجه ولز
#             <br>4: دروغ‌ها درباره دلیل حذف هنر
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>آدام کوردن از دروغهای ولز و حذف هنرش ابراز نارضایتی کرد. او همچنین از بیتوجهی ولز به جامعه هنری گلایه داشت. اما نارضایتی او مربوط به خطمشی جدید سایت در خصوص محتوای جنسی نیست، بلکه بیشتر مربوط به تصمیمگیریهای فردی ولز و نحوه برخورد او با جامعه هنری است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>آدام کوئردن، مدیر منابع مشترک، از دروغهای ولز و حذف هنرش ابراز نارضایتی کرد.</span></p>
#         <p><strong>Keywords:</strong> ['"آدام کوئردن"، "سرخوردگی"، "دروغ"، "حذف هنر"، "بیتوجهی"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 46:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>طوفان استوایی دانیل، که چهارمین طوفان در فصل طوفان‌های اقیانوس اطلس در سال 2010 است، در اقیانوس اطلس شرقی شکل گرفته است. طوفان، که در فاصله تقریبی 3000 مایل از میامی، فلوریدا واقع شده است، حداکثر پایداری سرعت وزش باد 40 مایل بر ساعت (64 کیلومتر بر ساعت) را دارد. دانشمندان مرکز ملی طوفان پیش بینی می کنند که دانیل تا روز چهارشنبه تقویت می‌شود و به یک طوفان تبدیل می‌شود. از آنجا که طوفان بسیار دورتر از سطح زمین است، ارزیابی تأثیر احتمالی آن بر ایالات متحده یا کارائیب همچنان دشوار است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>چرا اندازه‌گیری تأثیر احتمالی طوفان استوایی دانیل چالش‌برانگیز است؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: پیش‌بینی می‌شود این طوفان به یک توفند شدت یابد
#             <br>2: دانشمندان درباره پایداری سرعت وزش بادهای طوفان مطمئن نیستند
#             <br>3: طوفان خیلی از خشکی فاصله دارد
#             <br>4: طوفان فاصله خیلی زیادی از میامی دارد
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که طوفان دانیل در اقیانوس اطلس شرقی شکل گرفته و حدود 3000 مایل از میامی، فلوریدا فاصله دارد. همچنین، در ادامه بیان شده که به دلیل فاصله زیاد طوفان از خشکی، ارزیابی تأثیر احتمالی آن دشوار است. بنابراین، دلیل چالشبرانگیز بودن اندازهگیری تأثیر طوفان دانیل، فاصله زیاد آن از خشکی است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>طوفان استوایی دانیل در اقیانوس اطلس شرقی شکل گرفته و حدود 3000 مایل از میامی، فلوریدا فاصله دارد. دانشمندان مرکز ملی طوفان میگویند که ارزیابی تأثیر احتمالی طوفان بر ایالات متحده یا کارائیب دشوار است، زیرا طوفان بسیار دور از خشکی است.</span></p>
#         <p><strong>Keywords:</strong> ['"طوفان استوایی دانیل"، "اقیانوس اطلس شرقی"، "3000 مایل"، "میامی فلوریدا"، "فاصله از خشکی"، "ارزیابی تأثیر"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 47:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>در قدیم اینطور بود که وارث تاج و تخت درست پس از اتمام تحصیل به سربازی می‌رفت. با این حال، چارلز به دانشگاه در کالج ترینیتی در کمبریج رفت و در آنجا به تحصیل مردم‌شناسی و باستان‌شناسی مشغول شد، و بعدها به تاریخ پرداخت و مدرک 2:2 (مدرک با درجه دوم پایین) را کسب کرد. «چارلز» اولین عضو از خانواده سلطنتی بریتانیا بود که به او مدرک تحصیلی داده شده است.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>با توجه به متن، کدام مورد برای وارث تاج و تخت عادی در نظر گرفته می‌شود؟</span></p>
#         <p><strong>Original Answer:</strong> 2</p>
#         <p><strong>Predicted Answer:</strong> 2</p>
#         <p><strong>Options:</strong>
#             <br>1: دریافت مدرک 2:2
#             <br>2: رها کردن دانشگاه برای رفتن به سربازی
#             <br>3: مطالعه تاریخ
#             <br>4: تحصیل در دانشگاه پیش از رفتن به سربازی
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده است که در گذشته وارث تاج و تخت پس از "اتمام تحصیل" به سربازی میرفت. این به این معنی است که رفتن به سربازی پس از پایان یافتن تحصیلات عادی و مرسوم بوده است. بنابراین، گزینه 2 که اشاره به ترک دانشگاه برای رفتن به سربازی دارد، انتخاب صحیح است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>در قدیم اینطور بود که وارث تاج و تخت درست پس از اتمام تحصیل به سربازی میرفت.</span></p>
#         <p><strong>Keywords:</strong> ['"وارث تاج و تخت"، "سربازی"، "اتمام تحصیل"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 48:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>روز چهارشنبه، اتحادیه ملی بسکتبال ایالات متحده (NBA) به دلیل نگرانی در مورد کووید-19، فصل بسکتبال حرفه‌ای خود را به حالت تعلیق درآورد. تصمیم NBA به دنبال آزمایش مثبت ویروس کووید-19 بازیکن یوتا جاز بود.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>NBA تصمیم به تعلیق کدام مورد زیر گرفت؟</span></p>
#         <p><strong>Original Answer:</strong> 1</p>
#         <p><strong>Predicted Answer:</strong> 1</p>
#         <p><strong>Options:</strong>
#             <br>1: فصل بسکتبال
#             <br>2: یک بازیکن از یوتا جاز
#             <br>3: هر بازیکنی که تست کووید-19 او مثبت شد
#             <br>4: تیم بسکتبال یوتا جاز
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده که اتحادیه ملی بسکتبال (NBA) فصل بسکتبال حرفهای خود را به حالت تعلیق درآورد. این تصمیم به دنبال مثبت شدن آزمایش کووید-19 یکی از بازیکنان تیم یوتا جاز گرفته شد.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>اتحادیه ملی بسکتبال ایالات متحده (NBA) فصل بسکتبال حرفهای خود را به حالت تعلیق درآورد.</span></p>
#         <p><strong>Keywords:</strong> ['"اتحادیه ملی بسکتبال"، "فصل بسکتبال"، "کووید-19"، "یوتا جاز"']</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 49:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>پس از آنکه مشخص شد بسیاری از خانواده‌ها به دنبال کمک حقوقی برای جلوگیری از اخراج هستند، جلسه‌ای در تاریخ 20 مارس در «مرکز حقوق عام خلیج شرقی» برای مالباختگان کلاهبرداری مسکن برگزار شد. وقتی اجاره‌نشین‌ها شروع به درمیان گذاشتن چیزی کردند که برای آنها اتفاق افتاده بود، اکثر خانواده‌های درگیر ناگهان متوجه شدند که کارولین ویلسون از OHA پول‌پیش آن‌ها را به سرقت برده و از شهر متواری شده است. مستاجرین در باغ لاک وود بر این باورند که ممکن است 40 خانواده یا تعداد بیشتری با حکم اخراج روبرو شوند، زیرا دریافتند که پلیس OHA در حال بررسی سایر املاک مسکونی عمومی‌ در اوکلند است که ممکن است در دام کلاهبرداری مسکن گرفتار شده باشند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>مطابق با آنچه در متن بیان شد، کارولین ویلسون قبل از ترک شهر برای چه کسانی کار می‌کرد؟</span></p>
#         <p><strong>Original Answer:</strong> 3</p>
#         <p><strong>Predicted Answer:</strong> 3</p>
#         <p><strong>Options:</strong>
#             <br>1: مرکز حقوق عام خلیج شرقی
#             <br>2: پلیس اوکلند
#             <br>3: OHA
#             <br>4: باغ‌های لاک‌وود
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>در متن گفته شده کارولین ویلسون از OHA پول پیش خانوادهها را به سرقت برده و از شهر فرار کرده است. این نشان میدهد کارولین ویلسون قبل از ترک شهر برای OHA کار میکرده است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>وقتی اجارهنشینها شروع به درمیان گذاشتن چیزی کردند که برای آنها اتفاق افتاده بود، اکثر خانوادههای درگیر ناگهان متوجه شدند که کارولین ویلسون از OHA پولپیش آنها را به سرقت برده و از شهر متواری شده است.</span></p>
#         <p><strong>Keywords:</strong> []</p>
#     </div>
#     <div style='border: 2px solid black; padding: 10px; margin-bottom: 10px;'>
#         <p><strong>Row 50:</strong></p>
#         <p><strong>Passage:</strong> <span style='direction: rtl; text-align: right; display: block;'>مسافران ممکن است با انواعی از حیوانات موذی مواجه شوند که در مناطق بومی خودشان با آنها آشنایی نداشته‌اند. حیوانات موذی غذا را خراب می‌کنند، سبب آزار و اذیت می‌شوند یا در حالت بدتر سبب واکنش‌های حساسیت‌زا می‌شوند، زهر خود را پخش می‌کنند یا باعث انتقال عفونت‌ها می‌شوند. خود بیماری‌های عفونی یا حیوانات خطرناکی که می‌توانند افراد را با قدرت خود مجروح کنند یا بکشند، معمولاً با عنوان بلایا توصیف نمی‌شوند.</span></p>
#         <p><strong>Question:</strong> <span style='direction: rtl; text-align: right; display: block;'>انجام کدام‌یک از موارد زیر احتمالاً از یک حیوان موذی بعید است؟</span></p>
#         <p><strong>Original Answer:</strong> 4</p>
#         <p><strong>Predicted Answer:</strong> 4</p>
#         <p><strong>Options:</strong>
#             <br>1: سبب جوش زدن شدن
#             <br>2: حساسیت‌های پوستی
#             <br>3: انتقال عفونت
#             <br>4: سبب جراحت‌های شدید شدن
#         </p>
#         <p><strong>Explanation:</strong> <span style='direction: rtl; text-align: right; display: block;'>حیوانات موذی ممکن است باعث انتقال عفونت شوند، اما بعید است که باعث جراحتهای شدید شوند. جراحتهای شدید معمولاً با حیوانات خطرناک و قدرتمندتر مرتبط است که در متن به آنها اشاره شده است.</span></p>
#         <p><strong>Highlighted Context:</strong> <span style='direction: rtl; text-align: right; display: block;'>خود بیماریهای عفونی یا حیوانات خطرناکی که میتوانند افراد را با قدرت خود مجروح کنند یا بکشند، معمولاً با عنوان بلایا توصیف نمیشوند.</span></p>
#         <p><strong>Keywords:</strong> ["'حیوانات موذی'", "'خراب کردن غذا'", "'آزار و اذیت'", "'واکنشهای حساسیتزا'", "'زهر'", "'عفونت'", "'حیوانات خطرناک'", "'جراحت'", "'بیماریهای عفونی'"]</p>
#     </div>

# %%
df.to_csv('resulttt.csv')
